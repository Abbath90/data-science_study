# %% [markdown]
# # Курсовая работа. Блок 1
# *Pandas и Matplotlib*
#
# **NB!** Код должен быть с комментариями к каждому логическому блоку кода. В противном случае работа **не** будет принята. <br><br>
# Выполнение курсовой работы может потребовать использование дополнительных библиотек.
#
# <br><br>
# **Описание работы:**
#
# Перед вами стоит бизнес-задача – на основании имеющихся данных подготовить аналитический отчет, который в дальнейшем поможет продюсерам образовательных программ эффективно выстраивать стратегию по модернизированию и улучшению курсов. В начале отчета предлагается оформить емкий описательный блок по каждому курсу на основании рассчитанных показателей. Далее предлагается посчитать потенциальную нагрузку на преподавателей, чтобы оценить необходимость расширения штата сотрудников. Затем идет блок из двух пунктов по анализу качества контента курсов, где необходимо выявить проблемные модули, которые, возможно, требуют доработки. Также стоит задача выявить потенциальную сезонность. Наконец, предложено задание для самостоятельной разработки метрики успеваемости студентов для нахождения тех, кто значительно хуже справляются с прохождением курса. Каждый из пунктов анализа предполагается сопроводить аналитическим выводом на основании рассчитанных метрик.
#
# <br><br>
#
# _________
# Обозначения:<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(p)** – задание может быть выполнено после прохождения модулей по Pandas <br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(m)** – задание может быть выполнено после прохождения модуля по Matplotlib <br>
# &nbsp;&nbsp;&nbsp;&nbsp;⭐ – необязательное задание повышенной сложности
# _________
#
# [Codebook](#Codebook) <br>
# [1. Описание и начальная работа с данными](#1.1-Описание-и-начальная-работа-с-данными)<br>
# [2. Расчет потенциальной нагрузки на преподавателей](#2.-Расчет-потенциальной-нагрузки-на-преподавателей)<br>
# [3. Выявление проблемных модулей](#3.-Выявление-проблемных-модулей)<br>
# [4. Расчет конверсии](#4.-Расчет-конверсии) <br>
# [5. Метрика успеваемости ](#5.-Метрика-успеваемости)

# %% [markdown]
# ## Codebook
#
# `courses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `title` – название курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `field` – сфера, к которой относится курс <br> <br><br>
# `students.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `city` – город студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `birthday` – день рождения студента <br> <br><br>
# `course_contents.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `course_id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `module_title` – название модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_title` – название урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_token` – токен урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `is_video` – наличие видео *(true/false)* <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `is_homework` – наличие домашней работы *(true/false)* <br>
# <br><br>
# `progresses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `student_id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `course_id` – идентификатор курса <br> <br><br>
# `progress_phases.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `progress_id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `status` – статус прохождения урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `start_date` – дата начала <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `finish_date` – дата окончания <br>
# <br><br>

# %% [markdown]
# ## 1. Описание и начальная работа с данными
#
# Вам необходимо подготовить данные и описать их. Данные реальные и содержат пропущенные значения, а также лишние относительно друг друга данные. <br>
#
# Объедините датасеты (кроме `students.scv`) в один общий для дальнейшей работы. Отдельный датасет создайте для расчета среднего возраста студентов курсов (отдельный датасет со `students.scv` нужен, чтобы в основном не потерять значения в основном датасете из-за того, что не по всем студентам есть анкетные данные о дате рождения). <br> <br>
# Опишите данные: <br>
# 1. **(p)** Посчитайте
#       * общее количество курсов в датасете,
#       * количество модулей на каждом курсе,
#       * количество уроков в каждом модуле на каждом курсе,
#       * медианное количество уроков в модуле на каждом курсе,
#       * количество учеников на каждом курсе
#       * минимальный, максимальный, средний, медианный возраст студентов
#       * минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
# 2. **(m)** Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий количество студентов на каждом курсе. График должен иметь заголовок. Значения должны быть отсортированы. Цвет столбцов должен содержать информацию о сфере, к которой относится курс (то есть нужна легенда). Прозрачность должна стоять на отметке 0.1. На график должна быть нанесена линия медианы. У медианы должен быть свой цвет. Рамки у графика быть не должно ⭐
# 4.     На основании рассчитанных значений опишите данные (описание должно быть полным и покрывать все полученные выше метрики)
#
# _____________________________________________________________________

# %% [markdown]
# Для того, чтобы проверить, что вы правильно соединили все датасеты в основной (без `students.csv`), запустите аналогичный приведенному ниже запрос. Выдача должна совпадать. Имейте в виду, что названия некоторых столбцов были переименованы.

# %%
main[main.student_id == '768c2987a744c51ce64a5993a2a94eaf'] # проверка основного датасета
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fa7c70b92776> in <module>
# ----> 1 main[main.student_id == '768c2987a744c51ce64a5993a2a94eaf'] # проверка основного датасета
#
# NameError: name 'main' is not defined

# %%
#Объедините датасеты (кроме students.scv) в один общий для дальнейшей работы. Отдельный датасет создайте для расчета 
#среднего возраста студентов курсов (отдельный датасет со students.scv нужен, чтобы в основном не потерять значения 
#в основном датасете из-за того, что не по всем студентам есть анкетные данные о дате рождения).
'''импортируем модули, выгружаем каждый файл в отдельный датасет'''
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.axes as ax
from pandas.plotting import register_matplotlib_converters


ds1 = pd.read_csv("./Data_1/Data/course_contents.csv", encoding = "UTF-8")
ds2 = pd.read_csv("./Data_1/Data/courses.csv", encoding = "UTF-8")
ds3 = pd.read_csv("./Data_1/Data/progresses.csv", encoding = "UTF-8")
ds4 = pd.read_csv("./Data_1/Data/progress_phases.csv", encoding = "UTF-8")
stud = pd.read_csv("./Data_1/Data/students.csv", encoding = "UTF-8")
stud
# Out:
#           id_                                id              city    birthday
# 0        1325  35e8a1938b9a33d5e45c8f4451c4309a               NaN         NaN
# 1        7503  6c3e52be632fc50de9640147e4017dcd            Москва  1979-10-23
# 2        8972  2033122d7c9b24b36eebc468d5259642               NaN         NaN
# 3        9235  a6ae278c0eab719b3784e5ea147c128f            Москва         NaN
# 4        9588  51b25c9afd20d178ef3c07276df38e2d  Великий Новгород         NaN
# ...       ...                               ...               ...         ...
# 43825  124251  a65ccacbe0226b345f195d02e676aa04               NaN  2000-11-21
# 43826  124338  148f1375e4135e779053a0d4b2a63857               NaN  1999-10-20
# 43827  124363  05fa419f832fa78ad6e7a5f90b0f71e6               NaN         NaN
# 43828  124377  9ff58c490f6ee5b013e7f62140ee3d79               NaN  1998-04-18
# 43829  124445  5c02b021cef9b775bb874bf1658ffb58               NaN         NaN
#
# [43830 rows x 4 columns]

# %%
'''Через два промежуточных датасета, путём поочерёдного слияния исходных датасетов, создаём датасет dat. 
Удаляем ненужные столбцы.'''
temp1 = ds4.merge(ds3, how='left', left_on='progress_id', right_on='id')
temp2 = temp1.merge(ds2, how='left', left_on='course_id', right_on='id')
dat = temp2.merge(ds1, how='left')
dat = dat.drop(['id_x', 'id_y', 'Unnamed: 0'], axis=1)
dat
# Out:
#                              progress_id  module_number  lesson_number status  \
# 0       a387ab916f402cb3fbfffd29f68fd0ce              2              4   done
# 1       a387ab916f402cb3fbfffd29f68fd0ce              1              1   done
# 2       a387ab916f402cb3fbfffd29f68fd0ce              2              2   done
# 3       a387ab916f402cb3fbfffd29f68fd0ce              1              4   done
# 4       a387ab916f402cb3fbfffd29f68fd0ce              1              6   done
# ...                                  ...            ...            ...    ...
# 350672  ea9c93865c1de54a5079b7ae71c88683              3              2  start
# 350673  ea9c93865c1de54a5079b7ae71c88683              2              4   done
# 350674  ea9c93865c1de54a5079b7ae71c88683              2              3   done
# 350675  ea9c93865c1de54a5079b7ae71c88683              2              2   done
# 350676  ea9c93865c1de54a5079b7ae71c88683              3              1   done
#
# ...

# %%
#общее количество курсов в датасете найдем с помощью метода unique()
len(dat.course_id.unique())
# Out:
# 15

# %%
#количество модулей на каждом курсе найдем с помощью группировки датасета по столбцу title и метода nunique()
dat.groupby('title').module_title.nunique()
# Out:
# title
# Excel Базовый                           9
# Java-разработчик                       17
# Java-разработчик c нуля                 9
# JavaScript с нуля                      18
# PHP-разработчик с 0 до PRO. Часть 1     8
# SMM-маркетолог от А до Я               11
# UX-дизайн                              20
# Анимация интерфейсов                   21
# Веб-вёрстка для начинающих 2.0          8
# Веб-дизайн PRO 2.0                     17
# Веб-дизайн Базовый                     17
# Веб-дизайн с нуля 2.0                  19
# Веб-разработчик                        20
# Интернет-маркетолог от Ingate          18
# Руководитель digital-проектов          17
# Name: module_title, dtype: int64

# %%
#количество уроков в каждом модуле на каждом курсе найдем с помощью группировки по столбцам title и module_title и метода nunique()
dat.groupby(['title', 'module_title']).lesson_title.nunique().head(40)
# Out:
# title                    module_title
# Excel Базовый             Визуализация данных Excel                                      5
#                          Основной функционал Excel                                      11
#                          Основной функционал Excel (продолжение)                         7
#                          Сводные таблицы Excel                                           5
#                          Формулы и функции Excel. Более сложные формулы                  5
#                          Формулы и функции Excel. Введение                               3
#                          Формулы и функции Excel. Продолжаем работать с формулами        7
#                          Формулы и функции Excel. Работа с ошибками, проверка данных     5
#                          Экзаменационная работа                                          1
# Java-разработчик         Вводный модуль                                                  8
# ...

# %%
#медианное количество уроков в модуле на каждом курсе получим группировокй предыдущего результата по столбцу title и метода median()
dat.groupby(['title', 'module_title']).lesson_title.nunique().groupby(['title']).median()
# Out:
# title
# Excel Базовый                           5.0
# Java-разработчик                        7.0
# Java-разработчик c нуля                10.0
# JavaScript с нуля                       7.0
# PHP-разработчик с 0 до PRO. Часть 1     4.0
# SMM-маркетолог от А до Я                6.0
# UX-дизайн                               3.5
# Анимация интерфейсов                    3.0
# Веб-вёрстка для начинающих 2.0          7.0
# Веб-дизайн PRO 2.0                      5.0
# Веб-дизайн Базовый                      3.0
# Веб-дизайн с нуля 2.0                   4.0
# Веб-разработчик                         2.0
# Интернет-маркетолог от Ingate           6.5
# Руководитель digital-проектов           5.0
# Name: lesson_title, dtype: float64

# %%
#количество учеников на каждом курсе найдем аналогично п.2
dat.groupby(['title']).student_id.nunique()
# Out:
# title
# Excel Базовый                           782
# Java-разработчик                        763
# Java-разработчик c нуля                 581
# JavaScript с нуля                       966
# PHP-разработчик с 0 до PRO. Часть 1     854
# SMM-маркетолог от А до Я                506
# UX-дизайн                              1151
# Анимация интерфейсов                    598
# Веб-вёрстка для начинающих 2.0         2004
# Веб-дизайн PRO 2.0                     1711
# Веб-дизайн Базовый                      518
# Веб-дизайн с нуля 2.0                  2014
# Веб-разработчик                         628
# Интернет-маркетолог от Ingate          2168
# Руководитель digital-проектов           685
# Name: student_id, dtype: int64

# %%
#минимальный, максимальный, средний, медианный возраст студентов
'''Удалим строки с пропусками даты рождения, 
вычислим возраст студентов в годах, путём вычитания дня рождения студента от даты 22 июля 2019(дата создания файлов к курсовой)
в формате datetime и деления на 365(получается несущественная погрешность из-за високосных годов), 
и занесём возраст в столбец 'age'(хранит количество полных лет). Затем удалим всех студентов младше 14 и старше 90 лет 
(допускаем, что студентов младше 14 лет и старше 90 лет не существует, а указанные даты рождения - ошибки).
После этого можем спокойно расчитать требуемые параметры.'''

from datetime import datetime

def age_calc(date_str):
    countdown_date = '2019-07-22'
    countdown_date = datetime.strptime(countdown_date, '%Y-%m-%d').date()
    date_object = datetime.strptime(date_str, '%Y-%m-%d').date()
    return ((countdown_date - date_object).days // 365) 

stud.dropna(subset=['birthday'], inplace=True)
stud["age"] = stud.loc[:, 'birthday'].apply(age_calc)
stud = stud.drop(stud.loc[(stud['age'] < 14) | (stud['age'] > 90)].index)

stud_median = stud.describe().loc["50%"]["age"]
stud_min = stud.describe().loc["min"]["age"]
stud_max = stud.describe().loc["max"]["age"]
stud_mean = stud.describe().loc["mean"]["age"]

print("min={}, max={}, mean={}, median={}".format(stud_min, stud_max, np.around(stud_mean, decimals=2), stud_median))
# Out:
# min=14.0, max=89.0, mean=28.34, median=28.0

# %%
#минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
'''Соеденим таблицу студентов с таблицей соединяющей студентов и курсы, приведём получившуюся таблицу в порядок.
Затем, посчитаем необходимые характеристики и получим их в виде списка. После этого, для красивого вывода, разобьем список на
4 колонки и склеим получившийся фрейм из четырёх колонок с изначальным фреймом, удалив оттуда колонку со списком значений.
Наконец, соеденим итоговы фрейм с таблицей курсов, чтобы видеть название курса и сферу.'''

def my_describe(df):
    df_median = df.describe().loc["50%"]["age"]
    df_min = df.describe().loc["min"]["age"]
    df_max = df.describe().loc["max"]["age"]
    df_mean = df.describe().loc["mean"]["age"]
    return df_min, df_max, np.around(df_mean, decimals=2), df_median


stud_on_curs = stud.merge(ds3, how='left', left_on='id', right_on='student_id').drop(['id_y', 'student_id'], axis=1).rename(columns={'id_x' : 'id'})
temp = stud_on_curs.groupby(['course_id']).apply(my_describe) #.to_frame('describe_list')
temp = pd.DataFrame({'course_id':temp.index, 'describe_list':temp.values})
temp2 = pd.DataFrame(temp.describe_list.tolist(), columns=['min', 'max', 'mean', 'median'])
temp3 = temp.join(temp2).drop('describe_list', axis=1)
ds2.merge(temp3, how='left', left_on='id', right_on='course_id').drop(['Unnamed: 0', 'course_id'], axis=1)
# Out:
#                                   id                                title  \
# 0   943306102e5b067d08a29094f37b8193              Java-разработчик c нуля
# 1   17013cd19d25cb3f28dc1b2683721bb9                   Веб-дизайн Базовый
# 2   ac634845fb0350d0e9d49078aaa4b68f                        Excel Базовый
# 3   0770b1b039964228294f1f34b29fc2c1        Руководитель digital-проектов
# 4   abce125a877c2196a3bc7bfbc11b5fc5       Веб-вёрстка для начинающих 2.0
# 5   e9bb9205eeed307ee7cbaa08bfd166c3                    JavaScript с нуля
# 6   04ba6d0b40670c43a209141fa01fa784                 Анимация интерфейсов
# 7   c9fcb746d51e41bc5a217002d081454b                   Веб-дизайн PRO 2.0
# 8   dad6f6ffc086caa89e2f40c28a9c7490                            UX-дизайн
# 9   bf27a4bf4ada4c756451703ea62a914f        Интернет-маркетолог от Ingate
# 10  e3a0df907589d56692b5cb561fd90d87                Веб-дизайн с нуля 2.0
# 11  480d25ad36878fce09e7aada316ba1a6                      Веб-разработчик
# ...

# %%
#Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы.

stud_number = dat.groupby(['title']).student_id.nunique()
fig, subplot = plt.subplots()
subplot.bar(stud_number.index, stud_number)
plt.xlabel('Courses')
plt.ylabel('Students')
plt.title('Number of students')
plt.xticks(stud_number.index, rotation='vertical')
plt.show()

# %%
#Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий количество студентов на каждом
#курсе. График должен иметь заголовок. Значения должны быть отсортированы. Цвет столбцов должен содержать 
#информацию о сфере, к которой относится курс (то есть нужна легенда). Прозрачность должна стоять на отметке 0.1. 
#На график должна быть нанесена линия медианы. У медианы должен быть свой цвет. Рамки у графика быть не должно
'''Зададим функцию "field_color", которая возвращает определенный цвет в зависимости от значения параметра 'field'
в передаваемой строке. Применим её при указании аргумента 'color' при создании линий в методе barh(). 
Затем, после стандартных действий при отрисовке графика, создадим легенду. Легенда будет некорректна, поэтому нам надо 
отдельно переопределить линии(handles) и надписи(lables) для неё. Уберём повторы линий и вызовем легенду ещё раз.
'''
def field_color(row):
    colors = ['orange', 'teal', 'blue', 'red']
    if row['field'] == 'Business':
        return colors[0]
    elif row['field'] == 'Design':
        return colors[1]
    elif row['field'] == 'Development':
        return colors[2]
    elif row['field'] == 'Marketing':
        return colors[3]

    
stud_number = dat.groupby(['title', 'field']).student_id.nunique().to_frame().sort_values('student_id').reset_index()
fig, subplot = plt.subplots()
for i in stud_number.index:
    subplot.barh(stud_number.title[i], stud_number.student_id[i], alpha=0.5, color=field_color(stud_number.iloc[i]), \
                 label=stud_number.iloc[i].field)
plt.xlabel('Students')
plt.ylabel('Courses')
plt.title('Number of students')
subplot.spines['right'].set_visible(False)
subplot.spines['top'].set_visible(False)
plt.axvline(stud_number.student_id.median(), color='green', linewidth=2, label='median')

plt.legend()
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# <span style="color:green">*#На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)*.</span>
#
# Для анализа представлены 15 курсов по популярным направлениям в IT-сфере, разделенных на 4 области: Design, Marketing, Business и Development.
# Наибольшее количество модулей и уроков в них содержится в курсах раздела Development. Это можно объяснить спецификой данного направления.
# Наибольшее количество учеников на курсах представлено в группах Design и Development. Меньше всего представлено в группе Business.
# Медианный и средний возраст всех студентов равен 28 годам. Чуть постарше люди из группы Business, самая младшая аудитория - на курсах из раздела Design связанных с веб-дизайном.
# Суммируя вышесказанные выводы, можно констатировать, что курсы от skillbox, в основном, выбирают люди, с жизенным опытом, которые, по каким-либо причинам, решили сменить свою деятельность на IT-сферу. Более молодая аудитория выбирает веб-дизайн. Более старшая аудитория выбирает разработку или проектирование интерфейсов. Отдельно следует выделить область Business, со самой старшей аудиторией, которая, по всей видимости, состоит из людей, уже состоявшихся в IT или около IT-сфере и обучающиеся с целью повысить свои управленческие навыки.
#
# Можно заметить, что часть курсов некоторым образом дублируется. Это можно связать с тем, что часть курсов может быть разбита на два, чтобы потенциальыне студенты имели возможность гибкого выбра, при покупке курсов. Другой причиной можно назвать то, что некоторые курсы показали свою неэффективность, поэтому авторами были созданы новые курсы для новых потенциальных студентов.
#
# Для более полного анализа студентов и причинах выбора ими тех или иных курсов было бы интересно собрать больше метрик. Например, образование студентов, пол, опыт работы в сфере IT или других сферах. Эти данные помогли бы в разработке маркетинговых компаний. Но, не будем забывать, что имеющиеся данные, хоть и реальные, но представлены в учебных целях.

# %% [markdown]
# ## 2. Расчет потенциальной нагрузки на преподавателей
#
# 1. **(p)** Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). Считать дату начала прохождения курса студентом по дате начала первой домашней работы.
# 2. **(m)** На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.
# 3. **(m)** На основании первого пункта построить line-graph с несколькими линиями, отражающими прирост студентов в каждом месяце для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая прирост, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 4. **(p)** Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)
# 5. **(m)** Построить line-graph по четвертому пункту. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы
# 6. **(m)** Построить один line-graph для всех курсов по четвертому пункту. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая количество прогрессов, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 7. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
# Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). 
#Считать дату начала прохождения курса студентом по дате начала первой домашней работы.
'''Выделим из общего датафрейма только те строки, которые соотсветсвуют началу выполнения первого задания первого модуля 
каждого курса. Удалим все ненужные столбцы. Выделим из столбца "start_date" первые 10 символов, соответсвующих году 
месяцу и дню. Затем преобразуем значения этого столбца из формата строки в формат Datetime.
'''
def start_date_format(str):
    return str[0:10]

growth_stud = dat[dat['is_homework'] == True]
growth_stud = growth_stud.sort_values(['progress_id', 'title', 'module_number', 'lesson_number'])
growth_stud = growth_stud.groupby(['progress_id', 'title']).first().reset_index()
growth_stud = growth_stud.drop(['module_number', 'lesson_number', 'finish_date', 'student_id', 'course_id', 'status', 'field', 'module_title', 'lesson_title', 'lesson_token', 'is_video', 'is_homework'], axis=1)
growth_stud['start_date'] = growth_stud.loc[:, 'start_date'].apply(start_date_format)
growth_stud['start_date'] = pd.to_datetime(growth_stud['start_date'], format='%Y-%m-%d')
growth_stud.set_index('title', inplace=True)
growth_stud
# Out:
#                                                           progress_id  \
# title
# JavaScript с нуля                    0001849706a738920bbde91272740ec6
# Веб-дизайн с нуля 2.0                000962791295398b5ec7bc24f05269ac
# Интернет-маркетолог от Ingate        0015025693083f6e0385336a2e8bd945
# PHP-разработчик с 0 до PRO. Часть 1  00254314bc925a5200847889f760c989
# Веб-вёрстка для начинающих 2.0       00266b830acf7e7489f71e98f96e3246
# ...                                                               ...
# Веб-дизайн PRO 2.0                   ffcc07b34c06331a9e8c04f38159942b
# Веб-дизайн с нуля 2.0                ffd89df95e547be5e53ff2c3a5c2297b
# UX-дизайн                            fff13d719f65b695f24284cfad5ef462
# Excel Базовый                        fff54616f299a8b9c2891a58c6eaf67b
# Веб-вёрстка для начинающих 2.0       fffcd2f4b0d863c8384356b2ee19ae9f
#
#                                     start_date
# title
# JavaScript с нуля                   2018-11-24
# ...

# %%
'''Затем, создадим датафрейм "zero_dates", содержащий в строках интервалы длинной в месяц, начиная с марта 2016 года 
и заканчивая июлем 2019 года. Создадим список "list_of_titles" с названиями всех курсов. Опишем функцию "expand_grid", 
которая формирует датафрейм, в котором содержатся сочетания всех курсов по всем месяцам. 
Принимает в качестве аргумента словарь из заголовков столбцов и значений, по которым нужно сделать сочетания.
Применим эту функцию с словарю из списка "list_of_titles" и датафрейма "zero_dates", получив датасет month_set.
'''
import itertools

def expand_grid(data_dict):
    rows = itertools.product(*data_dict.values())
    return pd.DataFrame.from_records(rows, columns=data_dict.keys())

zero_dates = pd.date_range(start='3/1/2016', end='07/31/2019', freq='M')
list_of_titles = ds2['title'].tolist()
month_set = expand_grid({'title': list_of_titles, 'start_date': zero_dates,})
month_set
# Out:
#                        title start_date
# 0    Java-разработчик c нуля 2016-03-31
# 1    Java-разработчик c нуля 2016-04-30
# 2    Java-разработчик c нуля 2016-05-31
# 3    Java-разработчик c нуля 2016-06-30
# 4    Java-разработчик c нуля 2016-07-31
# ..                       ...        ...
# 610         Java-разработчик 2019-03-31
# 611         Java-разработчик 2019-04-30
# 612         Java-разработчик 2019-05-31
# 613         Java-разработчик 2019-06-30
# 614         Java-разработчик 2019-07-31
#
# [615 rows x 2 columns]

# %%
'''Опишем функцию "growth_of_stud", которая формирует датасет, показывающий, сколько новых студентов пришло на курс в каждом
месяце. Принимает на вход датафрейм и название курса. Выделяет данные только по курсу, соотвтевующему названию,
группирует их на периоды помесячно и подсчитывает количество студентов. Затем, формирует аналогичный датасет из датасета 
"month_set", но с нулевыми занчениями. После этого, объединяет два датасета с помощью метода "concat" таким образом, 
чтобы значения прироста студентов заменили нулевые значения из преобразованного "month_set", а остальные нулевые значения
остались на месте.
Применим функцию "growth_of_stud" к датафрейму "growth_stud" и к каждому элементу списка "list_of_titles" и выведем на экран, получив расчитанный прирост 
студентов помесячно, для каждого курса, в заданный пероид.
'''

def growth_of_stud(input_df, title):
    temp_df_growth_stud = input_df.loc[title]
    temp_df_growth_stud = temp_df_growth_stud.groupby(temp_df_growth_stud.start_date.dt.to_period("M")) \
        .agg('count').drop(['start_date'], axis=1) \
        .reset_index() \
        .rename(columns={'progress_id' : 'count'})

    temp_df_month_set = month_set.set_index('title').loc[title]
    temp_df_month_set = temp_df_month_set.groupby(temp_df_month_set.start_date.dt.to_period("M")) \
        .agg('count') \
        .drop(['start_date'], axis=1) \
        .reset_index()
    temp_df_month_set['count'] = 0

    result = pd.concat([temp_df_growth_stud, temp_df_month_set], join='outer',ignore_index=True, verify_integrity=True) \
        .sort_values(by=['start_date']) \
        .groupby('start_date') \
        .agg('sum') \
        .reset_index() \
        .rename(columns={'start_date' : 'year_month'})
    result['year_month'] = result.year_month.values.astype('datetime64[M]')
    return result


for i in list_of_titles:
    print(i, '\n', growth_of_stud(growth_stud, i))
# Out:
# Java-разработчик c нуля
#     year_month  count
# 0  2016-03-01      0
# 1  2016-04-01      0
# 2  2016-05-01      0
# 3  2016-06-01      0
# 4  2016-07-01      0
# 5  2016-08-01      0
# 6  2016-09-01      0
# 7  2016-10-01      0
# 8  2016-11-01      0
# 9  2016-12-01      0
# 10 2017-01-01      0
# 11 2017-02-01      0
# 12 2017-03-01      0
# 13 2017-04-01      0
# 14 2017-05-01      0
# 15 2017-06-01      0
# 16 2017-07-01      0
# 17 2017-08-01      0
# 18 2017-09-01      0
# 19 2017-10-01      0
# 20 2017-11-01      0
# 21 2017-12-01      0
# 22 2018-01-01      0
# 23 2018-02-01      0
# 24 2018-03-01      0
# 25 2018-04-01      0
# 26 2018-05-01      0
# 27 2018-06-01      0
# 28 2018-07-01      0
# 29 2018-08-01      0
# 30 2018-09-01      0
# 31 2018-10-01      0
# 32 2018-11-01      0
# 33 2018-12-01      0
# 34 2019-01-01      0
# 35 2019-02-01      0
# 36 2019-03-01     74
# 37 2019-04-01    109
# 38 2019-05-01     74
# 39 2019-06-01     98
# 40 2019-07-01     63
# ...

# %%
# На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса. 
#15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.
'''Опишем функцию "print_course_line_graph", которая рисует график line-graph. Она принимает на вход датафрейм, 
содержащий прирост студентов помесячно и заголовок курса. По оси x берутся месяцы из входного датафрейма, по оси y
берётся прирост студентов. Месяцы отражаются вертикально - для удобства. Наносятся названия осей и заголовок графика.
Применим эту функцию к результату функции "growth_of_stud" и к каждому элементу списка "list_of_titles". Получим 15 графиков 
line-graph, показывающими прирост студентов на каждом курсе, помесячно в заданный период.
'''
# %matplotlib inline

def print_course_line_graph(input_df, title):
    fig, subplot = plt.subplots()
    x_ticks = input_df['year_month']
    y_ticks = input_df['count']
    subplot.plot(x_ticks, y_ticks)
    subplot.set_title(title)
    subplot.set_xlabel('Month')
    subplot.set_ylabel('Count')
    x_labels = [pd.to_datetime(str(i)).strftime("%m-%y") for i in input_df['year_month']]
    plt.xticks(x_ticks, rotation='vertical', labels=x_labels)
    fig.tight_layout()
    plt.show()
    
for i in list_of_titles:
    print_course_line_graph(growth_of_stud(growth_stud, i), i)

# %%
#На основании первого пункта построить line-graph с несколькими линиями, отражающими прирост студентов в каждом месяце 
#для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок.
#Ось, отражающая прирост, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). 
#Рамок у графика быть не должно 
'''
Создадим список "courses" из датафреймов, содержащих прирост студентов помесячно. Анализ предыдущих датафреймов и графиков
из предыдущих двух пунктов показал, что с начала измерений, т.е. с марта 2017 года, до определённого момента, а именно до 
декабря 2017 года, на больешй части курсов вообще не было студентов. На остальных курсах было 1-2 студента. 
Можно сделать предположение, что это были тестовые студенты и ими на общем графике можно принебречь для "красоты" 
и для большей наглядности. Поэтому, проигнорируем период в 21 месяц, т.е. с марта 2016 года по декабрь 2017 года. 
Затем, создадим график, 
нанесём названия осей, зададим заголовок. После этого, пройдемся по списку "courses" в цикле, отрисовывая в каждой итерации
новый график и задавая название кривой в соостветсвтии с курсом. Затем, зададим легенду, вынеся её за график и отобразим её
в двух столбцах. Накоец, подпишем месяцы вертикально и уберём рамку, оставив оси.
В результате, получим график line-graph с 15 кривыми, отражающими прирост студентов в каждом месяце для каждого курса. 
'''
#growth_stud.set_index('start_date').resample('MS').size()

courses = []
for i in list_of_titles:
    courses.append(growth_of_stud(growth_stud, i).iloc[21:])
    
fig, subplot = plt.subplots()
subplot.set_title('Student growth')
subplot.set_xlabel('Month')
subplot.set_ylabel('Number of students') 
number_of_titile = 0
for i in courses:
    subplot.plot(i['year_month'], i['count'], label=list_of_titles[number_of_titile])
    number_of_titile += 1
plt.legend(frameon=False, ncol=2, bbox_to_anchor=(1, 1))
x_labels = [pd.to_datetime(str(i)).strftime("%m-%y") for i in courses[0]['year_month']]
plt.xticks(courses[0]['year_month'], rotation='vertical', labels=x_labels)
subplot.spines['right'].set_visible(False)
subplot.spines['top'].set_visible(False)
plt.show()

# %%
#Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю 
#(каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. 
#Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой 
#(такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)
'''
Удалим ненужные столбцы из исходного датафрейма и присовим результат датафрейму 'growth_progress'. 
Преобразуем столбцы 'start_date' и 'finish_date' в формат DdateTime. Ячейки в столбце 'finish_date',
заполненные значениями Nan, соответсвтующими невыполненому заданию, заполним значением 2019-07-22. Переведём оба столбца в 
формат Period помесячно. Создадим столбец 'delta_date' со значениями разности значений столбца 'finish_date' и 'start_date'.
РАсчёты будем производить в формате int, чтобы получить целочисленные значения в днях. 
Зададим список 'list_of_multi_progress'.
В цикле пройдёмся по всем строкам датафрейма 'growth_progress'. Если значение столбца 'delta_date' на текущей итерации 
больше нуля, т.е. домашнее задание выполнялось в период, занимающий более одного месяца, то попадём ещё в один цикл
по количеству месяцев, которое потребовалось на выполнение текущего ДЗ. В каждой итерации заносим в список 
'list_of_multi_progress' словарь, состоящий из ключа 'start_date' и значение первого месяца выполнения плюс 
значение счётчика. Таким образом мы разворачиваем каждое многомесячное ДЗ на отдельные месяцы.
Соеденим значения датафрейма 'growth_progress' и списка 'list_of_multi_progress' через метод concat().
Заполним значения Nan в столбце 'delta_date' нулями и удалим все ненулевые значения, удалив таким образом многомесячные
прогрессы, которые мы уже развернули и добавили в конец датафрейма. Удалим, также, ненужные столбцы.
'''
def start_date_format(str):
    return str[0:10]

growth_progress = dat[dat['is_homework'] == True]
growth_progress = growth_progress.sort_values(['progress_id', 'title', 'module_number', 'lesson_number'])
growth_progress = growth_progress.groupby(['progress_id', 'title', 'module_title']).first().reset_index()
growth_progress = growth_progress.drop(['module_number', 'lesson_number', 'student_id', 'course_id', 'status', 'field', 'module_title', 'lesson_title', 'lesson_token', 'is_video', 'is_homework'], axis=1)
growth_progress['start_date'] = growth_progress.loc[:, 'start_date'].apply(start_date_format)
growth_progress['start_date'] = pd.to_datetime(growth_progress['start_date'], format='%Y-%m-%d')
growth_progress['finish_date'] = growth_progress['finish_date'].fillna(value='2019-07-22')
growth_progress['finish_date'] = growth_progress.loc[:, 'finish_date'].apply(start_date_format)
growth_progress['finish_date'] = pd.to_datetime(growth_progress['finish_date'], format='%Y-%m-%d')

growth_progress = growth_progress.set_index('start_date').to_period('M').reset_index()
growth_progress = growth_progress.set_index('finish_date').to_period('M').reset_index()

growth_progress['delta_date'] = growth_progress['finish_date'].astype('int') - growth_progress['start_date'].astype('int')
list_of_multi_progress=[]

for i in growth_progress.index:
    if growth_progress['delta_date'][i] > 0:
        for j in range(growth_progress['delta_date'][i] + 1):
            list_of_multi_progress.append({'start_date': growth_progress['start_date'][i] + j, 'title': growth_progress['title'][i]}) 

growth_progress = pd.concat([growth_progress, pd.DataFrame(list_of_multi_progress)], ignore_index=True, sort=False)
growth_progress['delta_date'] = growth_progress['delta_date'].fillna(0)
growth_progress.drop(growth_progress[growth_progress['delta_date'] > 0].index, inplace=True)
growth_progress = growth_progress.drop(['finish_date', 'progress_id'], axis=1)
growth_progress
growth_progress
# Out:
#        start_date                           title  delta_date
# 0         2019-04               JavaScript с нуля         0.0
# 1         2019-04               JavaScript с нуля         0.0
# 3         2019-01               JavaScript с нуля         0.0
# 4         2018-11               JavaScript с нуля         0.0
# 5         2019-05               JavaScript с нуля         0.0
# ...           ...                             ...         ...
# 145921    2019-03  Веб-вёрстка для начинающих 2.0         0.0
# 145922    2019-04  Веб-вёрстка для начинающих 2.0         0.0
# 145923    2019-05  Веб-вёрстка для начинающих 2.0         0.0
# 145924    2019-06  Веб-вёрстка для начинающих 2.0         0.0
# 145925    2019-07  Веб-вёрстка для начинающих 2.0         0.0
#
# [123760 rows x 3 columns]

# %%
'''Опишем функцию "growth_of_progress" аналогично функции "growth_of_stud". И применим её в цикле с аргументами в виде 
датафрейма "growth_progress" и каждого элемента списка "list_of_titles". В итоге получим количество прогрессов 
по выполнению домашних работ помесячно для каждого курса в заданный промежуток времени.
'''
def growth_of_progress(input_df, title):
    temp_df_growth_progress = input_df.set_index('title').loc[title].rename(columns={'delta_date' : 'count'})

    temp_df_month_set = month_set.set_index('start_date')
    temp_df_month_set.index = temp_df_month_set.index.to_period('M')
    temp_df_month_set = temp_df_month_set.reset_index()
    
    result = pd.concat([temp_df_growth_progress, temp_df_month_set], join='outer',ignore_index=True, verify_integrity=True, sort=False) \
        .groupby('start_date').agg('count') \
        .reset_index() \
        .rename(columns={'start_date' : 'year_month'}) \
        .drop(['title'], axis=1)
    result['year_month'] = result.year_month.values.astype('datetime64[M]')

    return result


for i in list_of_titles:
    print(i, '\n', growth_of_progress(growth_progress, i))
# Out:
# Java-разработчик c нуля
#     year_month  count
# 0  2016-03-01      0
# 1  2016-04-01      0
# 2  2016-05-01      0
# 3  2016-06-01      0
# 4  2016-07-01      0
# 5  2016-08-01      0
# 6  2016-09-01      0
# 7  2016-10-01      0
# 8  2016-11-01      0
# 9  2016-12-01      0
# 10 2017-01-01      0
# 11 2017-02-01      0
# 12 2017-03-01      0
# 13 2017-04-01      0
# 14 2017-05-01      0
# 15 2017-06-01      0
# 16 2017-07-01      0
# 17 2017-08-01      0
# 18 2017-09-01      0
# 19 2017-10-01      0
# 20 2017-11-01      0
# 21 2017-12-01      0
# 22 2018-01-01      0
# 23 2018-02-01      0
# 24 2018-03-01      0
# 25 2018-04-01      0
# 26 2018-05-01      0
# 27 2018-06-01      0
# 28 2018-07-01      0
# 29 2018-08-01      0
# 30 2018-09-01      0
# 31 2018-10-01      0
# 32 2018-11-01      0
# 33 2018-12-01      0
# 34 2019-01-01      0
# 35 2019-02-01      0
# 36 2019-03-01    120
# 37 2019-04-01    367
# 38 2019-05-01    419
# 39 2019-06-01    615
# 40 2019-07-01    538
# ...

# %%
#Построить line-graph по четвертому пункту. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. 
#Ticks нужно развернуть так, чтобы они были читаемы
'''Применим функцию "print_course_line_graph" к результату функции "growth_of_progress" для каждого элемента в списке
"list_of_titles". Получим 15 графиков отражающих количество прогрессов по выполнению домашних работ помесячно 
для каждого курса в заданный промежуток времени.
'''
# %matplotlib inline

    
for i in list_of_titles:
    print_course_line_graph(growth_of_progress(growth_progress, i), i)

# %%
#Построить один line-graph для всех курсов по четвертому пункту. 15 линий на графике. 
#Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. 
#Ось, отражающая количество прогрессов, должна быть подписана. Линия для каждого курса должна иметь свой цвет 
#(нужна легенда). Рамок у графика быть не должно.
'''Сделаем всё аналогично пункту 2.3, только наполнять в начале и работать дальше мы будем со списоком "progress".
В итоге получим график с 15 кривыми, отражающими прирост прогрессов в каждом месяце для каждого курса.
'''

progress = []
for i in list_of_titles:
    progress.append(growth_of_progress(growth_progress, i).iloc[21:])
    
fig, subplot = plt.subplots()
subplot.set_title('Progress growth')
subplot.set_xlabel('Month')
subplot.set_ylabel('Number of progress') 
number_of_titile = 0
for i in progress:
    subplot.plot(i['year_month'], i['count'], label=list_of_titles[number_of_titile])
    number_of_titile += 1
plt.legend(frameon=False, ncol=2, bbox_to_anchor=(1, 1))
x_labels = [pd.to_datetime(str(i)).strftime("%m-%y") for i in progress[0]['year_month']]
plt.xticks(progress[0]['year_month'], rotation='vertical', labels=x_labels)
subplot.spines['right'].set_visible(False)
subplot.spines['top'].set_visible(False)
plt.show()

# %% [markdown]
# <span style="color:green">*#На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)*.</span>
#
# В данном разделе мы проанализируем прирост студентов на каждом курсе и прогресс выполненых заданий на каждом курсе.
#
# По некоторой части курсов данные по студентам и прогрессам начинаются с марта 2016 года. По другой части, в начале 2017 года. Но появления новых студентов и прогрессы по заданиям носят эпизодический характер. Резкий рост по большей части курсов начинается с декабря 2017 - января 2018 года. Это связано, по всей видимости, с тем, что в 2016-2017 годах велась разработка самой платформы, первых курсов, проводилось тестирование. Поэтому данные до декабря 2017 года можно не учитывать в анализе. В финальных графиках по каждой метрике эти данные отброшены.
#
# Также, подтвердился тезис из анализа предыдущего раздела о том, что некотоыре курсы были частично заменены другими, что оттянуло прирост студентов в них. Это курсы 'Веб-разработчик' и 'Веб-дизайн Базовый'. На графиках видно, что прирост студентов на них опустился почти до нуля.
#
# Можно заметить, что в начале каждого года наблюдается рост студентов, почти на каждом курсе. На части курсов заметен рост в начале лета. Это можно связать с психологическими и сезонными аспектами: наступление нового года многие люди воспринимают как повод начать обучаться чему-то новому, а с началом лета школьники и студенты уходят на каникулы и у них появляется больше свободного времени.
# Но, следует понимать, что прирост студентов, в первую очередь, зависит от маркетинговых компаний, проведение которых учитывает сезонность и психологические факторы. Было бы интересно, получить данные о затраченных средствах на макетинговые компании в соотсвтсвтующие периоды и посмотреть, корреляцию между двумя этими параметрами.
#
# Изменения количества прогрессов по ДЗ также подвережны сезонности. В начале года и в начале осени студенты более активны, нежели в весенее-летние месяцы. Прогрессы по ДЗ также зависят от количества новых студентов, очевидно, что чем больше студентов, тем больше выполненных ДЗ. Также, во время резкого роста количства студентов на курсе, резко растёт количество выполенных ДЗ. Это можно связать с тем. что первые ДЗ даются студентам обычно проще, так как изучаются азы и именно в это время у студентов имеется максимальный энтузиазм.
# Без очередного резкого увеличения студентов, количество прогрессов выполненных ДЗ падает. Это можно увидеть на примере курса 'java-разработчик'.

# %% [markdown]
# ## 3. Выявление проблемных модулей
#
# 1. **(p)** Рассчитать минимальное, максимальное, среднее, медианное время прохождения каждого модуля (разность между временем начала и окончания выполнения домашней работы) для каждого курса. Если домашних заданий в модуле несколько, то считать разность между временем начала выполнения первой домашней работы и временем окончания выполнения последней домашней работы в модуле
# 2. **(m)** На основании первого пункта построить line-graph с медианным временем прохождения каждого модуля для каждого курса. 15 графиков. Графики должны иметь заголовки
# 3. **(p)**  Чтобы выявить сезонность, посчитать медианное время выполнения домашней работы по месяцам (12 месяцев, январь-декабрь) для каждого курса.
# 4. **(m)** На основании третьего пункта построить line-graph, на который будут нанесены линии для каждого курса с медианным временем выполнения домашней работы по месяцам. 15 линий на графике. График должен иметь заголовок. Ось, отражающая время прохождения, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно  ⭐
# 5. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
#Рассчитать минимальное, максимальное, среднее, медианное время прохождения каждого модуля (разность между временем начала и 
#окончания выполнения домашней работы) для каждого курса. Если домашних заданий в модуле несколько, то считать разность между 
#временем начала выполнения первой домашней работы и временем окончания выполнения последней домашней работы в модуле.
'''Создадим датафрейм 'homework_dat' из изначального со значениями True в столбце 'is_homework'. Выделим только выполненные 
домашние работы и удалим ненужные столбцы. 
Переформатируем столбцы 'start_date' и 'finish_date', и создадим столбец 'delta_date', равный их разности, со значениями в днях.

Для случаев, если в модуле несколько ДЗ, мы не будем учитывать те, когда студент не сделал какое-либо из заданий. 
Будет учитываться старт первого задания и конец последнего из сделанных, даже если оно не последнее из списка или 
были пропущенные задания. Таких случаев не очень много, поэтому мы будем считать, что их обобщение не внесёт 
значительного искажения в аналитический отчёт.
'''

def start_date_format(str):
    return str[0:10]

homework_dat = dat[dat['is_homework'] == True]
homework_dat = homework_dat[homework_dat['status'] == 'done']
homework_dat = homework_dat.drop(['student_id', 'field', 'status', 'lesson_title', 'is_homework', 'lesson_token', 'is_video'], axis=1)

homework_dat['start_date'] = homework_dat.loc[:, 'start_date'].apply(start_date_format)
homework_dat['start_date'] = pd.to_datetime(homework_dat['start_date'], format='%Y-%m-%d')
homework_dat['finish_date'] = homework_dat.loc[:, 'finish_date'].apply(start_date_format)
homework_dat['finish_date'] = pd.to_datetime(homework_dat['finish_date'], format='%Y-%m-%d')
homework_dat = homework_dat.set_index('start_date').to_period('D').reset_index()
homework_dat = homework_dat.set_index('finish_date').to_period('D').reset_index()

homework_dat['delta_date'] = homework_dat['finish_date'].astype('int') - homework_dat['start_date'].astype('int')
homework_dat = homework_dat.sort_values(by=['progress_id', 'module_number', 'lesson_number'])
homework_dat
# Out:
#       finish_date  start_date                       progress_id  \
# 28184  2018-11-29  2018-11-24  0001849706a738920bbde91272740ec6
# 28178  2018-12-06  2018-12-03  0001849706a738920bbde91272740ec6
# 28183  2018-12-11  2018-12-10  0001849706a738920bbde91272740ec6
# 28177  2018-12-19  2018-12-13  0001849706a738920bbde91272740ec6
# 28175  2019-01-26  2019-01-24  0001849706a738920bbde91272740ec6
# ...           ...         ...                               ...
# 21503  2019-05-22  2019-05-15  fff13d719f65b695f24284cfad5ef462
# 21502  2019-05-30  2019-05-26  fff13d719f65b695f24284cfad5ef462
# 13056  2019-04-13  2019-04-10  fff54616f299a8b9c2891a58c6eaf67b
# 13058  2019-04-16  2019-04-12  fff54616f299a8b9c2891a58c6eaf67b
# 13057  2019-04-20  2019-04-18  fff54616f299a8b9c2891a58c6eaf67b
#
#        module_number  lesson_number                         course_id  \
# 28184              1              7  e9bb9205eeed307ee7cbaa08bfd166c3
# ...

# %%
'''Выделим все прогрессы, имеющие несколько ДЗ в модуле в отдельный датасет 'temp'.
'''

temp = homework_dat.groupby(['progress_id', 'title', 'module_title']).agg('count')
temp = temp[temp['lesson_number'] != 1].reset_index()
temp
# Out:
#                           progress_id                    title  \
# 0    0122a8db329ffa4df09ad1a53e349872       Веб-дизайн PRO 2.0
# 1    016103616d87a12386aed934e14fbde4       Веб-дизайн PRO 2.0
# 2    019eb8eef7dcf7588c0cdf5861f3e180       Веб-дизайн PRO 2.0
# 3    03f3f742dc7db38dfc9e07f1fd65575d       Веб-дизайн PRO 2.0
# 4    03fb2af73e054b427229223e5acdd84a       Веб-дизайн PRO 2.0
# ..                                ...                      ...
# 639  fec9ab3feb1bfec3833c0a34a0610ff4  Java-разработчик c нуля
# 640  fee0e141bbd6a242a3263b3fcdc13b07       Веб-дизайн PRO 2.0
# 641  ffa8b9ee7f1200cad45058ad06d60e66  Java-разработчик c нуля
# 642  ffa8b9ee7f1200cad45058ad06d60e66  Java-разработчик c нуля
# 643  ffa8b9ee7f1200cad45058ad06d60e66  Java-разработчик c нуля
#
#                    module_title  finish_date  start_date  module_number  \
# 0                 Введение в UX            2           2              2
# ...

# %%
'''Создадим датасет 'temp2' из 'homework_dat', со всеми ДЗ из модулей, имеющих несколько ДЗ. 
Как видно, их не так много, около 7%.
'''

temp2 = homework_dat[homework_dat['module_title'].isin(temp['module_title'].unique())].sort_values(['progress_id', 'module_title', 'lesson_number'])
temp2
# Out:
#       finish_date  start_date                       progress_id  \
# 9894   2019-02-22  2019-02-20  0034c5f05e57b0c36da784995e944b70
# 16424  2019-02-01  2018-12-21  00b312d5661cbec0d1d86f48e6e5290d
# 22202  2019-07-17  2019-07-15  00f27c3ed5c51326b31dadf1d630c913
# 34500  2019-05-08  2019-04-24  0122a8db329ffa4df09ad1a53e349872
# 34497  2019-05-14  2019-05-13  0122a8db329ffa4df09ad1a53e349872
# ...           ...         ...                               ...
# 8494   2019-05-15  2019-05-14  ffa8b9ee7f1200cad45058ad06d60e66
# 36916  2018-11-12  2018-11-03  ffad4ca873fb38ba960ece75abd81af7
# 36917  2018-11-18  2018-11-06  ffad4ca873fb38ba960ece75abd81af7
# 36912  2018-11-04  2018-10-28  ffad4ca873fb38ba960ece75abd81af7
# 39683  2018-10-27  2018-08-21  ffcc07b34c06331a9e8c04f38159942b
#
#        module_number  lesson_number                         course_id  \
# 9894               9              8  dad6f6ffc086caa89e2f40c28a9c7490
# ...

# %%
'''Просуммируем дни, затраченные на модули, состоящие из нескольких ДЗ. 
(при записи temp3 = temp2.groupby(['progress_id', 'module_title', 'title', 'module_number']).agg('sum').reset_index()
терялся столбец "start_date", который необходим дальше. Поэтому пришлось сделать аггрегирование по функции max, при которой 
дата не терялась, вытащить нужный столбец и вставить его в аналогичный датафрейм по функции sum. Как сделать по другому, 
я не придумал.)
'''

def func(df):
    df['delta_date'].sum()

temp3 = temp2.groupby(['progress_id', 'module_title', 'title', 'module_number']).agg('max').reset_index()


date_temp3 = temp3['start_date']
temp3 = temp2.groupby(['progress_id', 'module_title', 'title', 'module_number']).agg('sum').reset_index()
temp3.append(date_temp3)
temp3 = temp3.drop(['lesson_number'], axis=1)

temp3
# Out:
#                            progress_id                          module_title  \
# 0     0034c5f05e57b0c36da784995e944b70  Concept design: творчество в дизайне
# 1     00b312d5661cbec0d1d86f48e6e5290d                  Числа, строки и даты
# 2     00f27c3ed5c51326b31dadf1d630c913                  Числа, строки и даты
# 3     0122a8db329ffa4df09ad1a53e349872                         Введение в UX
# 4     016103616d87a12386aed934e14fbde4                         Введение в UX
# ...                                ...                                   ...
# 1426  ffa8b9ee7f1200cad45058ad06d60e66                  Числа, строки и даты
# 1427  ffad4ca873fb38ba960ece75abd81af7                   Массивы и коллекции
# 1428  ffad4ca873fb38ba960ece75abd81af7            Наследование и полиморфизм
# 1429  ffad4ca873fb38ba960ece75abd81af7                  Числа, строки и даты
# 1430  ffcc07b34c06331a9e8c04f38159942b                         Введение в UX
#
# ...

# %%
'''Создадим датафрейм 'temp4' из 'homework_dat', в который поместим те ДЗ, которые не входят в модули, имеющие несколько ДЗ.
'''

temp4 = homework_dat[~homework_dat['module_title'].isin(temp['module_title'].unique())].drop(['finish_date', 'lesson_number', 'course_id'], axis=1)
temp4
# Out:
#        start_date                       progress_id  module_number  \
# 28184  2018-11-24  0001849706a738920bbde91272740ec6              1
# 28178  2018-12-03  0001849706a738920bbde91272740ec6              2
# 28183  2018-12-10  0001849706a738920bbde91272740ec6              3
# 28177  2018-12-13  0001849706a738920bbde91272740ec6              4
# 28175  2019-01-24  0001849706a738920bbde91272740ec6              5
# ...           ...                               ...            ...
# 21503  2019-05-15  fff13d719f65b695f24284cfad5ef462              4
# 21502  2019-05-26  fff13d719f65b695f24284cfad5ef462              6
# 13056  2019-04-10  fff54616f299a8b9c2891a58c6eaf67b              1
# 13058  2019-04-12  fff54616f299a8b9c2891a58c6eaf67b              2
# 13057  2019-04-18  fff54616f299a8b9c2891a58c6eaf67b              3
#
#                    title                                       module_title  \
# 28184  JavaScript с нуля                                Знакомство с языком
# ...

# %%
'''Склеим 'temp4' и 'temp3'
'''

temp5 = pd.concat([temp4, temp3]).reset_index().drop(['index'], axis=1)
temp5
# Out:
# C:\Users\TImur\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.
#        delta_date  module_number                module_title  \
# 0               5              1         Знакомство с языком
# 1               3              2                      Основы
# 2               1              3                     Функции
# 3               6              4           Массивы и объекты
# 4               2              5                   Замыкания
# ...           ...            ...                         ...
# 43422          36              4        Числа, строки и даты
# 43423           9              5         Массивы и коллекции
# ...

# %%
'''Сгруппируем, отсортируем модули, внутри курсов и найдем требуемые параметры.
'''

temp6 = temp5.groupby(['title', 'module_title', 'module_number']).agg(['mean', 'median', 'max', 'min']).round(1).reset_index().sort_values(['title', 'module_number'])
temp6
# Out:
#                              title  \
#
# 1                    Excel Базовый
# 2                    Excel Базовый
# 5                    Excel Базовый
# 6                    Excel Базовый
# 4                    Excel Базовый
# ..                             ...
# 185  Руководитель digital-проектов
# 177  Руководитель digital-проектов
# 188  Руководитель digital-проектов
# 180  Руководитель digital-проектов
# 179  Руководитель digital-проектов
#
#                                           module_title module_number  \
#
# 1                            Основной функционал Excel             1
# 2              Основной функционал Excel (продолжение)             2
# 5                    Формулы и функции Excel. Введение             3
# 6    Формулы и функции Excel. Продолжаем работать с...             4
# 4       Формулы и функции Excel. Более сложные формулы             5
# ..                                                 ...           ...
# ...

# %%
#(m) На основании первого пункта построить line-graph с медианным временем прохождения каждого модуля для каждого курса. 
#15 графиков. Графики должны иметь заголовки
'''Построим 15 графиков, аналогичным способом, что и ранее.
'''

# %matplotlib inline

def print_module_line_graph(input_df, title):
    fig, subplot = plt.subplots()
    x_ticks = input_df[input_df['title'] == title]['module_title']
    y_ticks = input_df[input_df['title'] == title]['delta_date']['median']
    subplot.plot(x_ticks, y_ticks)
    subplot.set_title(title)
    subplot.set_xlabel('Module')
    subplot.set_ylabel('Days')
    plt.xticks(x_ticks, rotation='vertical')
    plt.show()
    
for i in list_of_titles:
    print_module_line_graph(temp6, i)

# %%
#(p) Чтобы выявить сезонность, посчитать медианное время выполнения домашней работы по месяцам (12 месяцев, январь-декабрь) 
#для каждого курса.
'''Возьмем датасет 'temp5', который был получен после склеивания датасета имеющего модули с единственным ДЗ и датасета 
с просуммированными ДЗ, если их было несколько в модуле.
Как и ранее, отбросим все данные до начала 2018 года, потому как они, как мы предположили, были получены в результате тестовой
активности, при создании курсов.
Переведём столбец 'start_date' в помесячный вид.
'''

temp8 = temp5.set_index(temp5['start_date']).to_timestamp('D').to_period('M').drop(['start_date'], axis=1).reset_index()
temp8 = temp8[temp8['start_date'] > '2017-12-31']
temp8['start_date'] = temp8.start_date.values.astype('datetime64[M]')
temp8
# Out:
#       start_date  delta_date  module_number  \
# 0     2018-11-01           5              1
# 1     2018-12-01           3              2
# 2     2018-12-01           1              3
# 3     2018-12-01           6              4
# 4     2019-01-01           2              5
# ...          ...         ...            ...
# 41991 2019-05-01           7              4
# 41992 2019-05-01           4              6
# 41993 2019-04-01           3              1
# 41994 2019-04-01           4              2
# 41995 2019-04-01           2              3
#
#                                             module_title  \
# 0                                    Знакомство с языком
# 1                                                 Основы
# 2                                                Функции
# 3                                      Массивы и объекты
# 4                                              Замыкания
# ...                                                  ...
# ...

# %%
'''Сгруппируем датасет по каждому курсу и помесячно. Найдем медиану для каждого месяца, внутри курса.
'''

temp8.groupby(['title', 'start_date']).median().drop(['module_number'], axis=1)[10:50]
# Out:
#                                     delta_date
# title                   start_date
# Excel Базовый           2018-12-01         4.0
#                         2019-01-01         2.0
#                         2019-02-01         3.0
#                         2019-03-01         3.0
#                         2019-04-01         2.0
#                         2019-05-01         3.0
#                         2019-06-01         2.0
#                         2019-07-01         2.0
# Java-разработчик        2018-01-01         2.0
#                         2018-02-01        32.0
#                         2018-03-01        16.0
#                         2018-04-01         6.0
#                         2018-05-01         6.0
#                         2018-06-01         8.0
#                         2018-07-01         6.0
#                         2018-08-01        14.0
#                         2018-09-01         9.5
#                         2018-10-01         8.0
# ...

# %%
#(m) На основании третьего пункта построить line-graph, на который будут нанесены линии для каждого курса с медианным временем 
#выполнения домашней работы по месяцам. 15 линий на графике. График должен иметь заголовок. Ось, отражающая время прохождения, 
#должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно.


fig, subplot = plt.subplots()
subplot.set_title('Median of homework time')
subplot.set_xlabel('Month')
subplot.set_ylabel('Mean')

for i in list_of_titles:
    temp9 = temp8[temp8['title'] == i].groupby(['start_date']).median()
    subplot.plot(temp9.index, temp9['delta_date'], label=i)
    
plt.legend(frameon=False, ncol=2, bbox_to_anchor=(1, 1))
plt.xticks(rotation='vertical')
subplot.spines['right'].set_visible(False)
subplot.spines['top'].set_visible(False)
plt.show()

# %% [markdown]
# <span style="color:green">#На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)</span>
#
# Проанализировав полученные метрики каждого модуля каждого курса, можно сделать вывод, что некоторые курсы составлены не совсем корректно. Имеются модули, которые вызывают у студентов заметные сложности. Логично было бы разделить такие модули на несколько. Например, модуль "Концептуальный дизайн" в курсе "Веб-дизайн PRO 2.0", идущий в самом начале, сильно выделяется по сравнению с остальными модулями данного курса. Или модуль по аналитике из курса "Руководитель digital-проектов" явно вызывает сложности.
# Но, в большинстве из рассматриваемых курсов, нагрузка распределена более или менее равномерно, с явным выделением по сложности финального экзаменационного модуля.
# Эти результаты отлично иллюстрируют предствленные графики.
#
# Что касается сезонности, то, ожидаемо, дольше всего студенты делают ДЗ в летние и зимние месяцы.
#
# При анализе имеющихся данных нужно учитывать ряд факторов:
# 1) Первые студенты, записавшиеся на новый курс, будут иметь больше проблем с выполнением ДЗ, нежели последующие студенты. Механизм проверки ДЗ к этому моменту ещё не отлажен, могут быть ошибки и опечатки в формулировании ДЗ. Первые студенты не имеют возможности попросить у других студентов в чате. Этим можно объяснить аномальный выброс на графке с медианным временем выполнения ДЗ для курса "Java-разработчик". Первые студенты дошли до сложных тем, связанных с GUI и не смогли быстро их решить. У последующих студентов это уже не вызвало таких трудностей.
# 2) Рабочие данные предствлены всего за два года, поэтому невозможно сделать корректные выводы о сезонности.
# 3) Курсы стартовали в разное время, поэтому сравнивать их по многим показателям не совсем корректно.

# %% [markdown]
# ## 4. Расчет конверсии
#
# 1. **(p)** Посчитать конверсию перехода студентов из одного модуля в другой на каждом курсе. Формула: отношение количества студентов, приступивших к выполнению домашнего задания в этом модуле (если дз в модуле несколько, то считать по первому дз в модуле), к количеству студентов, сдавших задание в предыдущем модуле (если дз в модуле несколько, то считать по последнему дз в модуле).
# 2. **(m)** Постройте bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. График должен иметь заголовок. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. 15 графиков. Графики должны иметь заголовки. Ticks должны содержать номер и название модуля. Цвет столбцов графиков должен содержать информацию о сфере, к которой относится курс (нужна легенда). Прозрачность должна стоять на отметке 0.1. На графики должна быть нанесена линия медианы конверсии для каждого курса. У медианы должен быть свой цвет. Рамок у графиков быть не должно ⭐
# 4. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
#Посчитать конверсию перехода студентов из одного модуля в другой на каждом курсе. Формула: отношение количества студентов, 
#приступивших к выполнению домашнего задания в этом модуле (если дз в модуле несколько, то считать по первому дз в модуле), 
#к количеству студентов, сдавших задание в предыдущем модуле (если дз в модуле несколько, то считать по последнему дз в модуле). 
'''Создадим датасет 'conversion_dat_last' из исходного, выбрав только ДЗ со статусом done. Для каждого прогресса, курса и модуля
выберем последее ДЗ и посчитаем их для каждого курса.
В курсе 'Анимация интерфейсов' модуль 'InVision Studio' закончило ноль человек. Вручную добавим соответствующую строку.
'''
conversion_dat_last = dat[(dat['is_homework'] == True) & (dat['status'] == 'done')]
conversion_dat_last = conversion_dat_last.sort_values(['progress_id', 'title', 'module_number', 'lesson_number'])
conversion_dat_last = conversion_dat_last.groupby(['progress_id', 'title', 'module_number']).last().reset_index()
conversion_dat_last = conversion_dat_last.groupby(['title', 'module_number', 'module_title', 'field']).count().reset_index().drop(['is_video', 'is_homework', 'progress_id', 'status', 'start_date', 'finish_date', 'student_id', 'course_id', 'lesson_title', 'lesson_token'], axis=1).rename(columns={'lesson_number' : 'sum'})
new_row = {'title':'Анимация интерфейсов', 'module_number':9, 'module_title':'InVision Studio', 'sum':0}
conversion_dat_last = conversion_dat_last.append(new_row, ignore_index=True)
conversion_dat_last = conversion_dat_last.sort_values(['title', 'module_number'])
conversion_dat_last.head(50)
# Out:
#                       title  module_number  \
# 0             Excel Базовый              1
# 1             Excel Базовый              2
# 2             Excel Базовый              3
# 3             Excel Базовый              4
# 4             Excel Базовый              5
# 5             Excel Базовый              6
# 6             Excel Базовый              7
# 7             Excel Базовый              8
# 8             Excel Базовый              9
# 9          Java-разработчик              1
# 10         Java-разработчик              2
# 11         Java-разработчик              3
# 12         Java-разработчик              4
# 13         Java-разработчик              5
# 14         Java-разработчик              6
# 15         Java-разработчик              7
# 16         Java-разработчик              8
# 17         Java-разработчик              9
# 18         Java-разработчик             10
# 19         Java-разработчик             11
# 20         Java-разработчик             12
# ...

# %%
'''Аналогично создадим датасет 'conversion_dat_first', содержащий первые с любым статусом в каждом модуле.
'''
conversion_dat_first = dat[dat['is_homework'] == True]
conversion_dat_first = conversion_dat_first.sort_values(['progress_id', 'title', 'module_number', 'lesson_number'])
conversion_dat_first = conversion_dat_first.groupby(['progress_id', 'title', 'module_number']).first().reset_index()
conversion_dat_first = conversion_dat_first.groupby(['title', 'module_number', 'module_title', 'field']).count().reset_index().drop(['is_video', 'is_homework', 'progress_id', 'status', 'start_date', 'finish_date', 'student_id', 'course_id', 'lesson_title', 'lesson_token'], axis=1).rename(columns={'lesson_number' : 'sum'})
conversion_dat_first.head(50)
# Out:
#                       title  module_number  \
# 0             Excel Базовый              1
# 1             Excel Базовый              2
# 2             Excel Базовый              3
# 3             Excel Базовый              4
# 4             Excel Базовый              5
# 5             Excel Базовый              6
# 6             Excel Базовый              7
# 7             Excel Базовый              8
# 8             Excel Базовый              9
# 9          Java-разработчик              1
# 10         Java-разработчик              2
# 11         Java-разработчик              3
# 12         Java-разработчик              4
# 13         Java-разработчик              5
# 14         Java-разработчик              6
# 15         Java-разработчик              7
# 16         Java-разработчик              8
# 17         Java-разработчик              9
# 18         Java-разработчик             10
# 19         Java-разработчик             11
# 20         Java-разработчик             12
# ...

# %%
'''Создадим пустой датасет 'conv_df'.
'''
conv_df_dic = [{'title': '', 'module_title': '', 'field': '', 'conversion': 0}]
conv_df = pd.DataFrame(conv_df_dic)
conv_df
# Out:
#   title module_title field  conversion
# 0                                    0

# %%
'''Заполним его, посчитав конверсию, согласно заданию, как отношение количества студентов, приступивших к выполнению 
домашнего задания в этом модуле (если дз в модуле несколько, то считать по первому дз в модуле), к количеству студентов, 
сдавших задание в предыдущем модуле и умножив результат на 100.
'''
for i in list_of_titles:
    for j in range(len(conversion_dat_first[conversion_dat_first['title'] == i]['sum'])):
        if j == len(conversion_dat_first[conversion_dat_first['title'] == i]['sum'])-1:
            break
        else:
            a_series = pd.Series([i, conversion_dat_first[conversion_dat_first['title'] == i]['module_title'].iloc(0)[j+1], \
                                  conversion_dat_first[conversion_dat_first['title'] == i]['field'].iloc(0)[j+1], \
                                  np.around(100*(conversion_dat_first[conversion_dat_first['title'] == i]['sum'].iloc(0)[j+1] / conversion_dat_last[conversion_dat_last['title'] == i]['sum'].iloc(0)[j]), decimals=2)], \
                                 index = conv_df.columns)
            conv_df = conv_df.append(a_series, ignore_index=True)
# Out:
# C:\Users\TImur\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in longlong_scalars
#   if sys.path[0] == '':

# %%
'''Посмотрим результат.
'''
conv_df = conv_df.drop([0])
conv_df.head(50)
# Out:
#                              title  \
# 1          Java-разработчик c нуля
# 2          Java-разработчик c нуля
# 3          Java-разработчик c нуля
# 4          Java-разработчик c нуля
# 5          Java-разработчик c нуля
# 6          Java-разработчик c нуля
# 7          Java-разработчик c нуля
# 8          Java-разработчик c нуля
# 9               Веб-дизайн Базовый
# 10              Веб-дизайн Базовый
# 11              Веб-дизайн Базовый
# 12              Веб-дизайн Базовый
# 13              Веб-дизайн Базовый
# 14              Веб-дизайн Базовый
# 15              Веб-дизайн Базовый
# 16              Веб-дизайн Базовый
# 17              Веб-дизайн Базовый
# 18              Веб-дизайн Базовый
# 19              Веб-дизайн Базовый
# 20                   Excel Базовый
# 21                   Excel Базовый
# 22                   Excel Базовый
# 23                   Excel Базовый
# 24                   Excel Базовый
# 25                   Excel Базовый
# ...

# %%
#Постройте bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. 
#График должен иметь заголовок. Ticks нужно развернуть так, чтобы они были читаемы
'''Построим bar-chart по каждому курсу, аналогично тому, как мы делали это в предыдущих пунктах.
'''

for i in list_of_titles:
    fig, subplot = plt.subplots()
    subplot.bar(conv_df[conv_df['title'] == i].module_title, conv_df[conv_df['title'] == i].conversion)
    plt.xlabel('Module')
    plt.ylabel('Conversion')
    plt.title(i)
    plt.xticks(rotation='vertical')
    plt.show()

# %%
'''Дополнительно, для большей информативности, построим bar-chart по каждому курсу, показывающий количество сданных ДЗ 
в каждом модуле.
'''

conversion_dat_last = conversion_dat_last.rename(columns={'sum' : 'sum_of_hw'})

for i in list_of_titles:
    fig, subplot = plt.subplots()
    subplot.bar(conversion_dat_last[conversion_dat_last['title'] == i].module_title.str.slice(stop=30), \
                conversion_dat_last[conversion_dat_last['title'] == i].sum_of_hw)
    plt.xlabel('Modules')
    plt.ylabel('Finished homeworks')
    plt.title(i)
    plt.xticks(rotation='vertical')
    plt.show()

# %%
#Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий конверсию перехода студентов из 
#одного модуля в другой на каждом курсе. 15 графиков. Графики должны иметь заголовки. Ticks должны содержать номер и название 
#модуля. Цвет столбцов графиков должен содержать информацию о сфере, к которой относится курс (нужна легенда). 
#Прозрачность должна стоять на отметке 0.1. На графики должна быть нанесена линия медианы конверсии для каждого курса. 
#У медианы должен быть свой цвет. Рамок у графиков быть не должно

'''Перепишем функцию "field_color" из первого раздела. Горизонтальный bar-chart посторим аналогично последнему заданию 
первого раздела. 
'''
def field_color(row):
    colors = ['orange', 'teal', 'blue', 'red']
    if list(row['field'])[0] == 'Business':
        return colors[0]
    elif list(row['field'])[0] == 'Design':
        return colors[1]
    elif list(row['field'])[0] == 'Development':
        return colors[2]
    elif list(row['field'])[0] == 'Marketing':
        return colors[3]

for i in list_of_titles:
    fig, subplot = plt.subplots()
    subplot.barh(conv_df[conv_df['title'] == i].module_title.str.slice(stop=30), conv_df[conv_df['title'] == i].conversion, alpha=0.5, color=field_color(conv_df[conv_df['title'] == i]), \
                 label=conv_df[conv_df['title'] == i].field.unique()[0])
    plt.xlabel('Module')
    plt.ylabel('Conversion')
    plt.title(i)
    plt.xticks(rotation='vertical')
    subplot.spines['right'].set_visible(False)
    subplot.spines['top'].set_visible(False)
    plt.axvline(conv_df[conv_df['title'] == i].conversion.median(), color='green', linewidth=2, label='median')
    plt.legend()
    plt.legend(bbox_to_anchor=(1.3, 1))
    plt.show()

# %% [markdown]
# <span style="color:green">#На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)</span>
#
# Целью анализа конверсии было выявить модули, выполнение которых вызывает сложности у студентов.
# Проанализировав полученные графики можно сделать вывод о том, что большинство модулей составлены корректно и конверсия перехода студентов близка к 100%. Выделяется модуль "InVision Studio" курса "Анимация интерфейсов", который закончило 0 человек.
# А также модули "Дизайн для не дизайнеров" и "Как писать хорошие тексты" курса "SMM-маркетолог от А до Я", которые явно вызвали проблемы у студентов.
# Графики сданных ДЗ по каждому курсу подтверждают картину. Почти все графики имеют вид нисходящей лестницы, кроме двух обозначенных курсов, что показывает, что нагрузка распределена от простого к сложному.

# %% [markdown]
# ## 5. Метрика успеваемости
#
# &nbsp;&nbsp;&nbsp;&nbsp;*(необязательное задание)*
#
# Иногда студенты берут курсы, которые оказываются для них неподъемными. Это может быть как по причинам недостаточной изначальной подготовки, так и по причинам, связанным с низкой мотивацией студента. Для улучшения качества контента полезно выявить причину. На основании имеющихся данных придумайте метрику успеваемости студента. **Обоснуйте ее.** Выявите таких студентов на каждом курсе, чтобы предоставить продюсерам список проблемных студентов.

# %%
len(dat.student_id.unique())
# Out:
# 9794

# %% [markdown]
# Выделим следующие группы студентов:
# 1. Тестовые студенты с прогрессами до 1 декабря 2017 года - их мы просто удалим
# 2. Студенты, записанные на один курс
#     1) закончившие или почти закончившие обучение (приступившие к последнему модулю)
#     2) начавшие заниматься недавно (менее двух месяцев до 22 июля 2019)
#     3) начавшие заниматься давно, но не сделавшие ни одного ДЗ
#     4) забросившие его на ранней стадии (менее 2 ДЗ)
#     5) Забросившие его, прорешав несколько модулей (2 и более ДЗ)
#     6) Закончившие или продолжающие заниматься
# 3. Студенты, записанные на несколько курсов
#     1) Перешедшие с одного курса на другой недавно
#     2) Перешедшие с одного курса на другой и забросившие его на ранней стадии (прогресс по всем курсам заброшен)
#     3) Перешедшие с одного курса на другой и забросившие его прорешав несколько модулей (прогресс по всем курсам заброшен)
#     4) Перешедшие с одного курса на другой (прогресс по одним курсам заброшен, но по другим завершён или в процессе)(или взято два курса, решается один, а второй оставлен на потом)
#     5) Занимающиеся на нескольких курсах сразу недавно
#     6) Занимающиеся на нескольких курсах сразу (прогресс по нескольким курсам завершен или в процессе)
#
# Попробуем выделить каждую из групп
#
# ---Посомтрим, как завершилось последнее заданине, фейл или дане

# %%
def start_date_format(str):
    return str[0:10]

failed_stud = dat.drop(['field', 'lesson_token', 'is_video'], axis=1)

failed_stud['start_date'] = failed_stud.loc[:, 'start_date'].apply(start_date_format)
failed_stud['start_date'] = pd.to_datetime(failed_stud['start_date'], format='%Y-%m-%d')
failed_stud['finish_date'] = failed_stud['finish_date'].fillna(value='2019-07-22')
failed_stud['finish_date'] = failed_stud.loc[:, 'finish_date'].apply(start_date_format)
failed_stud['finish_date'] = pd.to_datetime(failed_stud['finish_date'], format='%Y-%m-%d')
failed_stud = failed_stud.set_index('start_date').to_period('D').reset_index()
failed_stud = failed_stud.set_index('finish_date').to_period('D').reset_index()

failed_stud
# Out:
#        finish_date  start_date                       progress_id  \
# 0       2018-06-23  2018-06-23  a387ab916f402cb3fbfffd29f68fd0ce
# 1       2018-06-20  2018-06-20  a387ab916f402cb3fbfffd29f68fd0ce
# 2       2018-06-23  2018-06-23  a387ab916f402cb3fbfffd29f68fd0ce
# 3       2018-06-21  2018-06-20  a387ab916f402cb3fbfffd29f68fd0ce
# 4       2018-06-28  2018-06-21  a387ab916f402cb3fbfffd29f68fd0ce
# ...            ...         ...                               ...
# 350672  2019-07-22  2019-07-16  ea9c93865c1de54a5079b7ae71c88683
# 350673  2019-07-02  2019-07-02  ea9c93865c1de54a5079b7ae71c88683
# 350674  2019-07-01  2019-07-01  ea9c93865c1de54a5079b7ae71c88683
# 350675  2019-07-01  2019-06-30  ea9c93865c1de54a5079b7ae71c88683
# 350676  2019-07-15  2019-07-14  ea9c93865c1de54a5079b7ae71c88683
#
#         module_number  lesson_number status                        student_id  \
# 0                   2              4   done  768c2987a744c51ce64a5993a2a94eaf
# ...

# %%
'''Колличество студентов в группе 1'''
group1 = failed_stud[failed_stud['start_date'] < '2017-12-01'].student_id.unique()
len(group1)
# Out:
# 15

# %%
'''Удалим студентов группы 1 из общего датасета'''
failed_stud = failed_stud[~failed_stud['student_id'].isin(group1)]
failed_stud
# Out:
#        finish_date  start_date                       progress_id  \
# 0       2018-06-23  2018-06-23  a387ab916f402cb3fbfffd29f68fd0ce
# 1       2018-06-20  2018-06-20  a387ab916f402cb3fbfffd29f68fd0ce
# 2       2018-06-23  2018-06-23  a387ab916f402cb3fbfffd29f68fd0ce
# 3       2018-06-21  2018-06-20  a387ab916f402cb3fbfffd29f68fd0ce
# 4       2018-06-28  2018-06-21  a387ab916f402cb3fbfffd29f68fd0ce
# ...            ...         ...                               ...
# 350672  2019-07-22  2019-07-16  ea9c93865c1de54a5079b7ae71c88683
# 350673  2019-07-02  2019-07-02  ea9c93865c1de54a5079b7ae71c88683
# 350674  2019-07-01  2019-07-01  ea9c93865c1de54a5079b7ae71c88683
# 350675  2019-07-01  2019-06-30  ea9c93865c1de54a5079b7ae71c88683
# 350676  2019-07-15  2019-07-14  ea9c93865c1de54a5079b7ae71c88683
#
#         module_number  lesson_number status                        student_id  \
# 0                   2              4   done  768c2987a744c51ce64a5993a2a94eaf
# ...

# %%
'''Разделим всех студентов на группы с одним курсом - 'failed_stud_one' и с несколькими - 'failed_stud_multi' '''
temp = failed_stud.groupby(['student_id'])['title'].nunique()
failed_stud_one_list = temp[temp == 1]
failed_stud_multi_list = temp[temp > 1]

failed_stud_one = failed_stud[failed_stud['student_id'].isin(list(failed_stud_one_list.index))]
failed_stud_multi = failed_stud[failed_stud['student_id'].isin(list(failed_stud_multi_list.index))]

failed_stud_one
# Out:
#        finish_date  start_date                       progress_id  \
# 98      2019-02-26  2019-02-26  2041e707f186990fef40d6e5d869ddf6
# 99      2019-03-07  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# 100     2019-03-07  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# 101     2019-03-07  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# 102     2019-03-28  2019-03-28  2041e707f186990fef40d6e5d869ddf6
# ...            ...         ...                               ...
# 350672  2019-07-22  2019-07-16  ea9c93865c1de54a5079b7ae71c88683
# 350673  2019-07-02  2019-07-02  ea9c93865c1de54a5079b7ae71c88683
# 350674  2019-07-01  2019-07-01  ea9c93865c1de54a5079b7ae71c88683
# 350675  2019-07-01  2019-06-30  ea9c93865c1de54a5079b7ae71c88683
# 350676  2019-07-15  2019-07-14  ea9c93865c1de54a5079b7ae71c88683
#
#         module_number  lesson_number status                        student_id  \
# 98                  1              7   done  84d2010cc192eb3b4d73477cca78845b
# ...

# %%
'''Студентов в группе 2.'''
len(failed_stud_one.student_id.unique())
# Out:
# 6453

# %%
failed_stud_multi_temp = failed_stud_multi.groupby(['progress_id', 'title']).count()
failed_stud_multi_one_active = failed_stud_multi_temp[failed_stud_multi_temp['status'] < 4].reset_index()
failed_stud_multi_one_active = failed_stud_multi_one_active.groupby(['progress_id'])['title'].nunique()
#failed_stud_multi_has_active_one_list = failed_stud_multi_has_active[temp == 1]
#failed_stud_multi_has_active_multi_list = failed_stud_multi_has_active[temp > 1]

#183 студента у которых несколько курсов и во всех менее 3 прогрессов

# %%
failed_stud = failed_stud[~failed_stud['progress_id'].isin(failed_stud_multi_one_active.index)]
failed_stud
# Out:
#        finish_date  start_date                       progress_id  \
# 0       2018-06-23  2018-06-23  a387ab916f402cb3fbfffd29f68fd0ce
# 1       2018-06-20  2018-06-20  a387ab916f402cb3fbfffd29f68fd0ce
# 2       2018-06-23  2018-06-23  a387ab916f402cb3fbfffd29f68fd0ce
# 3       2018-06-21  2018-06-20  a387ab916f402cb3fbfffd29f68fd0ce
# 4       2018-06-28  2018-06-21  a387ab916f402cb3fbfffd29f68fd0ce
# ...            ...         ...                               ...
# 350672  2019-07-22  2019-07-16  ea9c93865c1de54a5079b7ae71c88683
# 350673  2019-07-02  2019-07-02  ea9c93865c1de54a5079b7ae71c88683
# 350674  2019-07-01  2019-07-01  ea9c93865c1de54a5079b7ae71c88683
# 350675  2019-07-01  2019-06-30  ea9c93865c1de54a5079b7ae71c88683
# 350676  2019-07-15  2019-07-14  ea9c93865c1de54a5079b7ae71c88683
#
#         module_number  lesson_number status                        student_id  \
# 0                   2              4   done  768c2987a744c51ce64a5993a2a94eaf
# ...

# %%
temp = failed_stud.groupby(['student_id'])['title'].nunique()
failed_stud_one_list = temp[temp == 1]
failed_stud_multi_list = temp[temp > 1]

failed_stud_one = failed_stud[failed_stud['student_id'].isin(list(failed_stud_one_list.index))]
failed_stud_multi = failed_stud[failed_stud['student_id'].isin(list(failed_stud_multi_list.index))]

len(failed_stud_one.student_id.unique())
# Out:
# 7792

# %%
'''Найдем студентов группы 2.1'''

last_module_list = dat.groupby('title').module_title.nunique().to_frame().reset_index()
failed_stud_one = failed_stud_one.merge(last_module_list, how='left', left_on=['title'], right_on=['title'])
failed_stud_one = failed_stud_one.rename(columns={'module_title_y' : 'last_module', 'module_title_x' : 'module_title'})
group2_1 = failed_stud_one[failed_stud_one['module_number'] == failed_stud_one['last_module']].student_id.unique()
len(group2_1)
# Out:
# 468

# %%
'''Удалим студентов группы 2.1 из датасета'''

failed_stud_one = failed_stud_one[~failed_stud_one['student_id'].isin(group2_1)]
failed_stud_one
# Out:
#        finish_date  start_date                       progress_id  \
# 0       2019-02-26  2019-02-26  2041e707f186990fef40d6e5d869ddf6
# 1       2019-03-07  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# 2       2019-03-07  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# 3       2019-03-07  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# 4       2019-03-28  2019-03-28  2041e707f186990fef40d6e5d869ddf6
# ...            ...         ...                               ...
# 207455  2019-07-22  2019-07-16  ea9c93865c1de54a5079b7ae71c88683
# 207456  2019-07-02  2019-07-02  ea9c93865c1de54a5079b7ae71c88683
# 207457  2019-07-01  2019-07-01  ea9c93865c1de54a5079b7ae71c88683
# 207458  2019-07-01  2019-06-30  ea9c93865c1de54a5079b7ae71c88683
# 207459  2019-07-15  2019-07-14  ea9c93865c1de54a5079b7ae71c88683
#
#         module_number  lesson_number status                        student_id  \
# 0                   1              7   done  84d2010cc192eb3b4d73477cca78845b
# ...

# %%
'''Найдем группу 2.2 и количество студентов в ней'''

group2_2 = failed_stud_one.sort_values(['student_id', 'title', 'module_number', 'lesson_number']).groupby(['student_id']).first().reset_index()
group2_2 = group2_2[group2_2['start_date'] >= '2019-05-22'].student_id.unique()
len(group2_2)
# Out:
# 1304

# %%
'''Удалим их'''
failed_stud_one = failed_stud_one[~failed_stud_one['student_id'].isin(group2_2)]
failed_stud_one
# Out:
#        finish_date  start_date                       progress_id  \
# 0       2019-02-26  2019-02-26  2041e707f186990fef40d6e5d869ddf6
# 1       2019-03-07  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# 2       2019-03-07  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# 3       2019-03-07  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# 4       2019-03-28  2019-03-28  2041e707f186990fef40d6e5d869ddf6
# ...            ...         ...                               ...
# 207348  2019-06-20  2019-06-20  2f9742d87b5c9cd7dc1a37c406084aaa
# 207349  2019-06-07  2019-06-07  2f9742d87b5c9cd7dc1a37c406084aaa
# 207350  2019-06-19  2019-06-11  2f9742d87b5c9cd7dc1a37c406084aaa
# 207351  2019-06-07  2019-06-07  2f9742d87b5c9cd7dc1a37c406084aaa
# 207352  2019-05-28  2019-05-28  2f9742d87b5c9cd7dc1a37c406084aaa
#
#         module_number  lesson_number status                        student_id  \
# 0                   1              7   done  84d2010cc192eb3b4d73477cca78845b
# ...

# %%
len(failed_stud_one.student_id.unique())
# Out:
# 6020

# %%
'''Найдем группу 2.3. Разделим студентов на 2 подгруппы. Тех, кто не приступал ни к одному ДЗ и тех, кто приступал только к ДЗ.
Последних оказалось двое.'''

temp = failed_stud_one.groupby(['student_id'])['is_homework'].unique()
group2_3_1 = []
group2_3_2 = []
temp = temp.to_frame().reset_index()
for i, j in enumerate(temp['student_id']):
    if temp[temp['student_id'] == j].is_homework[i].tolist() == [False]:
        group2_3_1.append(j)
    if temp[temp['student_id'] == j].is_homework[i].tolist() == [True]:
        group2_3_2.append(j)

group2_3 = group2_3_1 + group2_3_2      
len(group2_3)
# Out:
# 914

# %%
'''Удалим их'''
failed_stud_one = failed_stud_one[~failed_stud_one['student_id'].isin(group2_3)]
failed_stud_one
# Out:
#        finish_date  start_date                       progress_id  \
# 0       2019-02-26  2019-02-26  2041e707f186990fef40d6e5d869ddf6
# 1       2019-03-07  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# 2       2019-03-07  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# 3       2019-03-07  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# 4       2019-03-28  2019-03-28  2041e707f186990fef40d6e5d869ddf6
# ...            ...         ...                               ...
# 207348  2019-06-20  2019-06-20  2f9742d87b5c9cd7dc1a37c406084aaa
# 207349  2019-06-07  2019-06-07  2f9742d87b5c9cd7dc1a37c406084aaa
# 207350  2019-06-19  2019-06-11  2f9742d87b5c9cd7dc1a37c406084aaa
# 207351  2019-06-07  2019-06-07  2f9742d87b5c9cd7dc1a37c406084aaa
# 207352  2019-05-28  2019-05-28  2f9742d87b5c9cd7dc1a37c406084aaa
#
#         module_number  lesson_number status                        student_id  \
# 0                   1              7   done  84d2010cc192eb3b4d73477cca78845b
# ...

# %%
len(failed_stud_one.student_id.unique())
# Out:
# 5106

# %%
'''Определим критерий заброшенности для группы 2.4. Пусть это будут студенты, выполневшие менее трёх ДЗ и дата сдачи последнего
ДЗ была более 3 месяцев назад. Здесь и далее будем считать успеваемость студентов группы 2. по ДЗ, поэтому выделим их из всех
прогрессов.'''
failed_stud_one = failed_stud_one[failed_stud_one['is_homework'] == True]
failed_stud_one
# Out:
#        finish_date  start_date                       progress_id  \
# 5       2019-03-18  2019-03-11  2041e707f186990fef40d6e5d869ddf6
# 13      2019-03-03  2019-02-26  2041e707f186990fef40d6e5d869ddf6
# 19      2019-07-22  2019-03-31  2041e707f186990fef40d6e5d869ddf6
# 21      2019-03-31  2019-03-18  2041e707f186990fef40d6e5d869ddf6
# 26      2019-03-09  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# ...            ...         ...                               ...
# 207310  2019-07-15  2019-07-13  1f85423dc45ff6b70d4dcc799ef09cff
# 207313  2019-04-05  2019-03-29  1f85423dc45ff6b70d4dcc799ef09cff
# 207337  2019-06-07  2019-05-29  2f9742d87b5c9cd7dc1a37c406084aaa
# 207338  2019-07-22  2019-07-15  2f9742d87b5c9cd7dc1a37c406084aaa
# 207350  2019-06-19  2019-06-11  2f9742d87b5c9cd7dc1a37c406084aaa
#
#         module_number  lesson_number status                        student_id  \
# 5                   4              4   done  84d2010cc192eb3b4d73477cca78845b
# ...

# %%
'''Найдем группу 2.4'''

group2_4 = failed_stud_one[failed_stud_one['finish_date'] <= '2019-04-22'].groupby(['student_id'])['is_homework'].count()
group2_4 = group2_4[group2_4 <= 2].index
len(group2_4)
# Out:
# 2087

# %%
'''Удалим их'''
failed_stud_one = failed_stud_one[~failed_stud_one['student_id'].isin(group2_4)]
failed_stud_one
# Out:
#        finish_date  start_date                       progress_id  \
# 5       2019-03-18  2019-03-11  2041e707f186990fef40d6e5d869ddf6
# 13      2019-03-03  2019-02-26  2041e707f186990fef40d6e5d869ddf6
# 19      2019-07-22  2019-03-31  2041e707f186990fef40d6e5d869ddf6
# 21      2019-03-31  2019-03-18  2041e707f186990fef40d6e5d869ddf6
# 26      2019-03-09  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# ...            ...         ...                               ...
# 207310  2019-07-15  2019-07-13  1f85423dc45ff6b70d4dcc799ef09cff
# 207313  2019-04-05  2019-03-29  1f85423dc45ff6b70d4dcc799ef09cff
# 207337  2019-06-07  2019-05-29  2f9742d87b5c9cd7dc1a37c406084aaa
# 207338  2019-07-22  2019-07-15  2f9742d87b5c9cd7dc1a37c406084aaa
# 207350  2019-06-19  2019-06-11  2f9742d87b5c9cd7dc1a37c406084aaa
#
#         module_number  lesson_number status                        student_id  \
# 5                   4              4   done  84d2010cc192eb3b4d73477cca78845b
# ...

# %%
len(failed_stud_one.student_id.unique())
# Out:
# 3019

# %%
'''Определим критерий заброшенности для группы 2.5. Пусть это будут студенты, у которых время выполнения последнего ДЗ 
со статусами started, wait или failed в четыре раза выше, чем медианное по этому модулю или со времени сдачи последнего 
ДЗ со статусом done прошло более 4 месяцев.'''


failed_stud_one['delta_date'] = failed_stud_one['finish_date'].astype('int') - failed_stud_one['start_date'].astype('int')

failed_stud_one = failed_stud_one.merge(temp6, how='left', left_on=['title', 'module_title', 'module_number'], right_on=['title', 'module_title', 'module_number'])
failed_stud_one = failed_stud_one.drop([('delta_date', 'mean'), ('delta_date', 'max'), ('delta_date', 'min')], axis=1)
failed_stud_one = failed_stud_one.rename(columns={('delta_date', 'median') : 'median'})
failed_stud_one
# Out:
# C:\Users\TImur\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       finish_date  start_date                       progress_id  \
# 0      2019-03-18  2019-03-11  2041e707f186990fef40d6e5d869ddf6
# 1      2019-03-03  2019-02-26  2041e707f186990fef40d6e5d869ddf6
# 2      2019-07-22  2019-03-31  2041e707f186990fef40d6e5d869ddf6
# 3      2019-03-31  2019-03-18  2041e707f186990fef40d6e5d869ddf6
# 4      2019-03-09  2019-03-07  2041e707f186990fef40d6e5d869ddf6
# ...           ...         ...                               ...
# 16252  2019-07-15  2019-07-13  1f85423dc45ff6b70d4dcc799ef09cff
# 16253  2019-04-05  2019-03-29  1f85423dc45ff6b70d4dcc799ef09cff
# ...

# %%
failed_stud_one = failed_stud_one.sort_values(['student_id', 'module_number', 'lesson_number'])
failed_stud_one
# Out:
#      finish_date  start_date                       progress_id  module_number  \
# 2934  2019-02-26  2019-02-22  1cc97f5958d104e3df6547dab3f39888              1
# 2931  2019-03-04  2019-02-26  1cc97f5958d104e3df6547dab3f39888              3
# 2937  2019-03-12  2019-03-04  1cc97f5958d104e3df6547dab3f39888              4
# 2933  2019-03-19  2019-03-18  1cc97f5958d104e3df6547dab3f39888              5
# 2930  2019-03-23  2019-03-20  1cc97f5958d104e3df6547dab3f39888              7
# ...          ...         ...                               ...            ...
# 3620  2018-09-28  2018-09-25  32bd5e7996c922942b08f9858728656b              8
# 3625  2018-10-01  2018-09-30  32bd5e7996c922942b08f9858728656b              9
# 3617  2018-10-30  2018-10-27  32bd5e7996c922942b08f9858728656b             10
# 3618  2019-01-17  2018-11-04  32bd5e7996c922942b08f9858728656b             11
# 3627  2019-07-22  2019-02-25  32bd5e7996c922942b08f9858728656b             12
#
# ...

# %%
'''Найдем группу 2.5 и сколько в ней студентов'''

group2_5 = failed_stud_one[(failed_stud_one['status'].isin(['wait', 'start', 'fail']) & (failed_stud_one['delta_date'] > 4*failed_stud_one['median'])) | (failed_stud_one['status'].isin(['done']) & (failed_stud_one['delta_date'] > 120))].student_id.unique()
len(group2_5)
# Out:
# 1996

# %%
'''Удалим их'''
failed_stud_one = failed_stud_one[~failed_stud_one['student_id'].isin(group2_5)]
failed_stud_one
# Out:
#      finish_date  start_date                       progress_id  module_number  \
# 1526  2019-05-21  2019-05-18  59879823dde4383fe4a36e814936707b              1
# 1527  2019-06-02  2019-05-21  59879823dde4383fe4a36e814936707b              2
# 1528  2019-06-30  2019-06-10  59879823dde4383fe4a36e814936707b              3
# 1525  2019-07-02  2019-06-24  59879823dde4383fe4a36e814936707b              4
# 8055  2018-05-03  2018-04-30  b86c7c6fe7a401adb71cbac33304bda3              1
# ...          ...         ...                               ...            ...
# 4046  2019-06-27  2019-05-30  a15989487d8ed47b7bf3755e41d6f6a8              3
# 4041  2019-06-26  2019-06-21  a15989487d8ed47b7bf3755e41d6f6a8              4
# 4042  2019-07-02  2019-06-27  a15989487d8ed47b7bf3755e41d6f6a8              5
# 4044  2019-07-22  2019-07-01  a15989487d8ed47b7bf3755e41d6f6a8              6
# 4040  2019-07-22  2019-07-15  a15989487d8ed47b7bf3755e41d6f6a8              7
#
# ...

# %%
'''Определим группу 2.6 и сколько в ней студентов'''

group2_6 = failed_stud_one.student_id.unique()
len(group2_6)
# Out:
# 1023

# %%
failed_stud_multi.sort_values(['student_id', 'title', 'module_number', 'lesson_number'])
# Out:
#        finish_date  start_date                       progress_id  \
# 119230  2019-02-11  2018-08-23  0061859057ae4a8bee5a491c0c214ad3
# 119229  2019-02-11  2019-02-11  0061859057ae4a8bee5a491c0c214ad3
# 119236  2019-02-11  2019-02-11  0061859057ae4a8bee5a491c0c214ad3
# 119231  2019-02-11  2019-02-11  0061859057ae4a8bee5a491c0c214ad3
# 119239  2019-02-11  2019-02-11  0061859057ae4a8bee5a491c0c214ad3
# ...            ...         ...                               ...
# 267159  2019-04-30  2019-04-30  b1d592cf0b04567737f157780383512e
# 267150  2019-04-30  2019-04-30  b1d592cf0b04567737f157780383512e
# 267215  2019-04-30  2019-04-30  b1d592cf0b04567737f157780383512e
# 267139  2019-04-30  2019-04-30  b1d592cf0b04567737f157780383512e
# 267152  2019-05-05  2019-05-01  b1d592cf0b04567737f157780383512e
#
#         module_number  lesson_number status                        student_id  \
# 119230              1              1   done  0066366dd4098a6ab35fa7eccc0b300a
# ...

# %% [markdown]
# С оставшимися студентами можно проделать действия аналогичные второй группе, но рассматривать прогрессы, а не студентов.
# Мы сможем выявить законченные курсы, заброшенные и те, которые ещё в процессе.
# В данных недостаёт отметки о том, переходил ли студент на другой курс. Мы уверены, что данная информация имеется, поэтому при окончательной обработке студентов и принятии решнеия, к какому студенту какие мотивационные действия применять (звонок/письмо, скидка/подарок) можно будет учитывать этот фактор.

# %%
len(failed_stud_multi.student_id.unique())
# Out:
# 1804

# %%
len(failed_stud_multi.progress_id.unique())
# Out:
# 4467

# %%
last_module_list = dat.groupby('title').module_title.nunique().to_frame().reset_index()
failed_stud_multi = failed_stud_multi.merge(last_module_list, how='left', left_on=['title'], right_on=['title'])
failed_stud_multi = failed_stud_multi.rename(columns={'module_title_y' : 'last_module', 'module_title_x' : 'module_title'})
group3_1 = failed_stud_multi[failed_stud_multi['module_number'] == failed_stud_multi['last_module']]
group3_1
# Out:
#        finish_date  start_date                       progress_id  \
# 198     2019-07-22  2019-04-19  b431e4ed2a994d9a8435553c52967ffe
# 466     2019-04-10  2019-04-10  18399470693c5dc5d429c0ff2cacbf5f
# 501     2019-05-10  2019-04-10  18399470693c5dc5d429c0ff2cacbf5f
# 502     2019-04-10  2019-04-10  18399470693c5dc5d429c0ff2cacbf5f
# 512     2019-04-10  2019-04-10  18399470693c5dc5d429c0ff2cacbf5f
# ...            ...         ...                               ...
# 137422  2018-09-13  2018-09-13  d4c14bc88e62f20c1eb19f0cd11fc8aa
# 137423  2018-09-13  2018-09-13  d4c14bc88e62f20c1eb19f0cd11fc8aa
# 137427  2018-09-13  2018-09-13  d4c14bc88e62f20c1eb19f0cd11fc8aa
# 137772  2019-04-23  2018-05-08  bcb874de65a688fa3c2e80c1758c706d
# 137845  2019-04-05  2018-12-06  37a32fb74bb042cd0cbb70fbd00754ed
#
#         module_number  lesson_number status                        student_id  \
# 198                21              1  start  d3687c1d9beb51f8ebc7f7b2b595c8b4
# ...

# %%
print(len(group3_1.student_id.unique()), len(group3_1.progress_id.unique()))

#Т.е. 581 студент завершили или почти завершили 672 курса.
# Out:
# 581 672

# %%
failed_stud_multi = failed_stud_multi[~failed_stud_multi['progress_id'].isin(group3_1.progress_id.unique())]
failed_stud_multi
# Out:
#        finish_date  start_date                       progress_id  \
# 0       2018-06-23  2018-06-23  a387ab916f402cb3fbfffd29f68fd0ce
# 1       2018-06-20  2018-06-20  a387ab916f402cb3fbfffd29f68fd0ce
# 2       2018-06-23  2018-06-23  a387ab916f402cb3fbfffd29f68fd0ce
# 3       2018-06-21  2018-06-20  a387ab916f402cb3fbfffd29f68fd0ce
# 4       2018-06-28  2018-06-21  a387ab916f402cb3fbfffd29f68fd0ce
# ...            ...         ...                               ...
# 138158  2019-06-04  2019-06-04  258e4bf0dcad5785877d8a40f7e633db
# 138159  2019-07-22  2019-06-04  258e4bf0dcad5785877d8a40f7e633db
# 138160  2019-06-04  2019-06-04  258e4bf0dcad5785877d8a40f7e633db
# 138161  2019-06-04  2019-06-04  258e4bf0dcad5785877d8a40f7e633db
# 138162  2019-06-04  2019-06-04  258e4bf0dcad5785877d8a40f7e633db
#
#         module_number  lesson_number status                        student_id  \
# 0                   2              4   done  768c2987a744c51ce64a5993a2a94eaf
# ...

# %%
group3_2 = failed_stud_multi.sort_values(['student_id', 'title', 'module_number', 'lesson_number']).groupby(['progress_id']).first().reset_index()
group3_2 = group3_2[group3_2['start_date'] >= '2019-05-22']
group3_2
# Out:
#                            progress_id finish_date  start_date  module_number  \
# 14    00ede07bc0adb9eac26766bed5b5d85f  2019-06-08  2019-06-08              1
# 27    01dcca9e980286558e1341f0f174cbf9  2019-07-11  2019-07-11              1
# 34    026168d21c229cfcd11003ce06a30da1  2019-07-10  2019-07-10              1
# 60    04d6a29aa875fbf3b524b391cb5ef2ad  2019-06-04  2019-06-04              1
# 100   0765b23fcb20ca9a4ff4458b01edb2ec  2019-05-26  2019-05-26              1
# ...                                ...         ...         ...            ...
# 3716  f9b2b18946d4810f96dde2b30ae99110  2019-06-11  2019-06-11              1
# 3723  f9ed4cb98758a4d18dbb94a916866e60  2019-07-15  2019-07-15              1
# 3736  fb3ee633fdd0321a98b37589059567ce  2019-06-04  2019-06-04              1
# 3768  fd70a90b4ef877a57c33b1769dbe3370  2019-06-20  2019-06-20              1
# 3781  fea4f5914796fec82d809adae77e3139  2019-06-02  2019-06-02              1
#
# ...

# %%
print(len(group3_2.student_id.unique()), len(group3_2.progress_id.unique()))
# Out:
# 148 199

# %%
failed_stud_multi = failed_stud_multi[~failed_stud_multi['progress_id'].isin(group3_2.progress_id.unique())]
failed_stud_multi
# Out:
#        finish_date  start_date                       progress_id  \
# 0       2018-06-23  2018-06-23  a387ab916f402cb3fbfffd29f68fd0ce
# 1       2018-06-20  2018-06-20  a387ab916f402cb3fbfffd29f68fd0ce
# 2       2018-06-23  2018-06-23  a387ab916f402cb3fbfffd29f68fd0ce
# 3       2018-06-21  2018-06-20  a387ab916f402cb3fbfffd29f68fd0ce
# 4       2018-06-28  2018-06-21  a387ab916f402cb3fbfffd29f68fd0ce
# ...            ...         ...                               ...
# 138151  2019-03-11  2019-03-11  cfe1eca3286b492c32e95d2fa17274d2
# 138152  2019-03-20  2019-03-20  cfe1eca3286b492c32e95d2fa17274d2
# 138153  2019-03-21  2019-03-18  cfe1eca3286b492c32e95d2fa17274d2
# 138154  2019-03-14  2019-03-13  cfe1eca3286b492c32e95d2fa17274d2
# 138155  2019-04-07  2019-04-07  cfe1eca3286b492c32e95d2fa17274d2
#
#         module_number  lesson_number status                        student_id  \
# 0                   2              4   done  768c2987a744c51ce64a5993a2a94eaf
# ...

# %%
temp = failed_stud_multi.groupby(['progress_id'])['is_homework'].unique()
group3_3_1 = []
group3_3_2 = []
temp = temp.to_frame().reset_index()
for i, j in enumerate(temp['progress_id']):
    if temp[temp['progress_id'] == j].is_homework[i].tolist() == [False]:
        group3_3_1.append(j)
    if temp[temp['progress_id'] == j].is_homework[i].tolist() == [True]:
        group3_3_2.append(j)

group3_3 = group3_3_1 + group3_3_2      
len(group3_3)
# Out:
# 247

# %%
group3_3
# Out:
# ['001c5c23ccdaffc9257b1b38c51d858d',
#  '00e35c7e46cb5019f3c791b7dd91036b',
#  '03057bed470953e52ba74e93dde1cbb0',
#  '03673e750a6410ef0c6488532e1cb897',
#  '0549f5e42fa93aa30a42dcfe911fe8dc',
#  '06cb8dae0db00de429fb81f25ca765c1',
#  '071fa76e8a034036aa32550489b3b4bd',
#  '079efe3b889354c2e48d776814590c12',
#  '0883698c8537f59451b504d9958ef911',
#  '0be7ef7300964d1ff930a359c3ca3d56',
#  '0c94de0bbf46dfb11e0f33262a8402c3',
#  '0f0f596a16119a6106afe309c6a13ad9',
#  '0f83ee9eac80bb074733c5bc72d0c0d9',
#  '0f9c87b8681f4cac0c7274756ea18d52',
#  '114832b36dd6f9e56a9985310e77a692',
#  '11ae7a559c6e574d142f6d4428c98ca4',
#  '1245da941ff1062e533cfa031c48d8c8',
#  '13307afcb34764db01e47c237cd0c3f8',
#  '1369dbf05d609e360ec56607ec695021',
#  '146c5bee30230f33c77f4a901c486ca5',
#  '1690e69da9670f42b9eca0296907a321',
#  '16a2262d548ca2ae1ea68f10b84f65f4',
#  '197c0e1ac4770e3736e9f5c3687b52bb',
#  '1a2e9daad25e14f2c5c62b60d7394f7e',
#  '1a9204ba3c12d31c494877c741a4054d',
# ...

# %%
failed_stud_multi = failed_stud_multi[~failed_stud_multi['progress_id'].isin(group3_3)]
failed_stud_multi
# Out:
#        finish_date  start_date                       progress_id  \
# 0       2018-06-23  2018-06-23  a387ab916f402cb3fbfffd29f68fd0ce
# 1       2018-06-20  2018-06-20  a387ab916f402cb3fbfffd29f68fd0ce
# 2       2018-06-23  2018-06-23  a387ab916f402cb3fbfffd29f68fd0ce
# 3       2018-06-21  2018-06-20  a387ab916f402cb3fbfffd29f68fd0ce
# 4       2018-06-28  2018-06-21  a387ab916f402cb3fbfffd29f68fd0ce
# ...            ...         ...                               ...
# 138151  2019-03-11  2019-03-11  cfe1eca3286b492c32e95d2fa17274d2
# 138152  2019-03-20  2019-03-20  cfe1eca3286b492c32e95d2fa17274d2
# 138153  2019-03-21  2019-03-18  cfe1eca3286b492c32e95d2fa17274d2
# 138154  2019-03-14  2019-03-13  cfe1eca3286b492c32e95d2fa17274d2
# 138155  2019-04-07  2019-04-07  cfe1eca3286b492c32e95d2fa17274d2
#
#         module_number  lesson_number status                        student_id  \
# 0                   2              4   done  768c2987a744c51ce64a5993a2a94eaf
# ...

# %%
failed_stud_multi = failed_stud_multi[failed_stud_multi['is_homework'] == True]
failed_stud_multi
# Out:
#        finish_date  start_date                       progress_id  \
# 4       2018-06-28  2018-06-21  a387ab916f402cb3fbfffd29f68fd0ce
# 7       2019-07-22  2018-06-23  a387ab916f402cb3fbfffd29f68fd0ce
# 12      2019-07-22  2018-03-11  a97393fe164b448e7231c07d48c82f9e
# 17      2018-02-20  2018-02-19  a97393fe164b448e7231c07d48c82f9e
# 28      2018-10-05  2018-10-02  000962791295398b5ec7bc24f05269ac
# ...            ...         ...                               ...
# 138121  2019-05-24  2019-05-22  ec0d53d87ce9162416214d0ce89938f0
# 138130  2019-03-13  2019-03-11  cfe1eca3286b492c32e95d2fa17274d2
# 138135  2019-07-22  2019-04-07  cfe1eca3286b492c32e95d2fa17274d2
# 138148  2019-04-04  2019-03-24  cfe1eca3286b492c32e95d2fa17274d2
# 138153  2019-03-21  2019-03-18  cfe1eca3286b492c32e95d2fa17274d2
#
#         module_number  lesson_number status                        student_id  \
# 4                   1              6   done  768c2987a744c51ce64a5993a2a94eaf
# ...

# %%
group3_4 = failed_stud_multi[failed_stud_multi['finish_date'] <= '2019-04-22'].groupby(['progress_id'])['is_homework'].count()
group3_4 = group3_4[group3_4 <= 2]
len(group3_4)
# Out:
# 1142

# %%
failed_stud_multi = failed_stud_multi[~failed_stud_multi['progress_id'].isin(group3_4.index)]
failed_stud_multi
# Out:
#        finish_date  start_date                       progress_id  \
# 28      2018-10-05  2018-10-02  000962791295398b5ec7bc24f05269ac
# 36      2019-01-23  2019-01-14  000962791295398b5ec7bc24f05269ac
# 37      2019-01-17  2018-10-09  000962791295398b5ec7bc24f05269ac
# 39      2019-07-22  2019-01-21  000962791295398b5ec7bc24f05269ac
# 44      2019-01-21  2019-01-20  000962791295398b5ec7bc24f05269ac
# ...            ...         ...                               ...
# 138121  2019-05-24  2019-05-22  ec0d53d87ce9162416214d0ce89938f0
# 138130  2019-03-13  2019-03-11  cfe1eca3286b492c32e95d2fa17274d2
# 138135  2019-07-22  2019-04-07  cfe1eca3286b492c32e95d2fa17274d2
# 138148  2019-04-04  2019-03-24  cfe1eca3286b492c32e95d2fa17274d2
# 138153  2019-03-21  2019-03-18  cfe1eca3286b492c32e95d2fa17274d2
#
#         module_number  lesson_number status                        student_id  \
# 28                  7              5   done  fcd7b6853c2582372980dd6af56d3bdc
# ...

# %%
failed_stud_multi['delta_date'] = failed_stud_multi['finish_date'].astype('int') - failed_stud_multi['start_date'].astype('int')

failed_stud_multi = failed_stud_multi.merge(temp6, how='left', left_on=['title', 'module_title', 'module_number'], right_on=['title', 'module_title', 'module_number'])
failed_stud_multi = failed_stud_multi.drop([('delta_date', 'mean'), ('delta_date', 'max'), ('delta_date', 'min')], axis=1)
failed_stud_multi = failed_stud_multi.rename(columns={('delta_date', 'median') : 'median'})
failed_stud_multi
# Out:
# C:\Users\TImur\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       finish_date  start_date                       progress_id  \
# 0      2018-10-05  2018-10-02  000962791295398b5ec7bc24f05269ac
# 1      2019-01-23  2019-01-14  000962791295398b5ec7bc24f05269ac
# 2      2019-01-17  2018-10-09  000962791295398b5ec7bc24f05269ac
# 3      2019-07-22  2019-01-21  000962791295398b5ec7bc24f05269ac
# 4      2019-01-21  2019-01-20  000962791295398b5ec7bc24f05269ac
# ...           ...         ...                               ...
# 11234  2019-05-24  2019-05-22  ec0d53d87ce9162416214d0ce89938f0
# ...

# %%
group3_5 = failed_stud_multi[(failed_stud_multi['status'].isin(['wait', 'start', 'fail']) & (failed_stud_multi['delta_date'] > 4*failed_stud_multi['median'])) | (failed_stud_multi['status'].isin(['done']) & (failed_stud_multi['delta_date'] > 120))].progress_id.unique()
len(group3_5)
# Out:
# 1619

# %%
failed_stud_multi = failed_stud_multi[~failed_stud_multi['progress_id'].isin(group3_5)]
failed_stud_multi
# Out:
#       finish_date  start_date                       progress_id  \
# 13     2019-07-03  2019-07-02  73e17a05355852fe65b785c82c37d1ad
# 14     2019-07-22  2019-07-11  73e17a05355852fe65b785c82c37d1ad
# 25     2019-07-09  2019-06-24  d8f96c352ebf58682962795577fb01bc
# 26     2019-07-22  2019-07-10  d8f96c352ebf58682962795577fb01bc
# 27     2019-06-21  2019-06-18  04ace4fe130d90c801e24eea13ee808e
# ...           ...         ...                               ...
# 11140  2019-06-08  2019-05-29  96d11030950a82f8dcf85269e7d3137c
# 11225  2019-07-22  2019-07-15  06d124dc91b1e50a57d2092de2aee15e
# 11232  2019-05-29  2019-05-28  ec0d53d87ce9162416214d0ce89938f0
# 11233  2019-05-28  2019-05-27  ec0d53d87ce9162416214d0ce89938f0
# 11234  2019-05-24  2019-05-22  ec0d53d87ce9162416214d0ce89938f0
#
#        module_number  lesson_number status                        student_id  \
# 13                 1              6   done  ed235f47e16da6e83d3f1cb511f38ea6
# ...

# %%
group3_6 = failed_stud_multi.progress_id.unique()
len(group3_6)
# Out:
# 588

# %%
len(failed_stud_multi.student_id.unique())
# Out:
# 526

# %%
group2_4
# Out:
# Index(['0010ab47e706e3ae6ac718d5cf06b752', '00114204df65ed8458822835b928393c',
#        '001b192f899a84496be98b41906246fc', '00386b771938472b2df62108f5985c1e',
#        '00afd9cac8338a68451ae7ac89d760e1', '00b7c91719ecefaa9a1ef0a4f2bc21fe',
#        '00c4c470fa4b144a6e516af856dbdd20', '00c7cd8ec0064fec2a4e963ac5441c34',
#        '00d77c720aab425e5dfcd3e368c5699d', '011606c06b711aad1d978dd3a66d7f81',
#        ...
#        'ff12c486cab990438c5e9b742f05ebde', 'ff325c29a720dca31b1c5c43c9c21c86',
#        'ff67d1c23bb6655502db7a5130b560f6', 'ff7f326a0547ac061779ea5685aec73b',
#        'ff93baa4ef5caa1a9b964c800a5e295a', 'ffa96fc7af520a0dee7bdc7f7763332b',
#        'ffb51e8fec9ca41f5f0d88aa34542e39', 'ffb687843c211c094de229b2fb9bbfbe',
#        'ffc165fc00d0172ec1bea5397e67ade8', 'ffd7a91bcf8acfe1afd2e74c7374cf23'],
#       dtype='object', name='student_id', length=2087)

# %%
import random

dat[dat['student_id'] == random.choice(group3_2.student_id.unique())].sort_values(['title', 'module_number', 'lesson_number'])
# Out:
#                              progress_id  module_number  lesson_number status  \
# 175217  e64ef295ae2660f8757ed09dff6491a3              1              1   done
# 175245  e64ef295ae2660f8757ed09dff6491a3              1              2   done
# 175242  e64ef295ae2660f8757ed09dff6491a3              1              3   done
# 175218  e64ef295ae2660f8757ed09dff6491a3              1              4   done
# 175209  e64ef295ae2660f8757ed09dff6491a3              1              5   done
# ...                                  ...            ...            ...    ...
# 349140  d35a065e6e023b0c7bb30b76f54f53ef              5              9   done
# 349142  d35a065e6e023b0c7bb30b76f54f53ef              5             10   done
# 349108  d35a065e6e023b0c7bb30b76f54f53ef              5             11   wait
# 349114  d35a065e6e023b0c7bb30b76f54f53ef              5             12   done
# 349104  d35a065e6e023b0c7bb30b76f54f53ef              5             13  start
#
# ...

# %%
# Например студент f19b1aed02db71b1e8c1fd6fa774217a, имеет 3 курса, по двум из которых есть незаконченный прогресс, а третий он закончил
# Очень многие студенты начали курс Веб-дизайн PRO 2.0 и потом перешли на Веб-дизайн с нуля 2.0
dat[dat['student_id'] == 'db75a51a0f39b2174ad5e913e2f83b4d'].sort_values(['title', 'module_number', 'lesson_number']).head(50)
# Out:
#                              progress_id  module_number  lesson_number status  \
# 175217  e64ef295ae2660f8757ed09dff6491a3              1              1   done
# 175245  e64ef295ae2660f8757ed09dff6491a3              1              2   done
# 175242  e64ef295ae2660f8757ed09dff6491a3              1              3   done
# 175218  e64ef295ae2660f8757ed09dff6491a3              1              4   done
# 175209  e64ef295ae2660f8757ed09dff6491a3              1              5   done
# 175238  e64ef295ae2660f8757ed09dff6491a3              1              6   done
# 175244  e64ef295ae2660f8757ed09dff6491a3              1              7   done
# 175234  e64ef295ae2660f8757ed09dff6491a3              1              8   done
# 175204  e64ef295ae2660f8757ed09dff6491a3              2              1   done
# 175227  e64ef295ae2660f8757ed09dff6491a3              2              2   done
# 175190  e64ef295ae2660f8757ed09dff6491a3              2              3   done
# ...

# %%
dat[dat['title'] == 'Веб-дизайн PRO 2.0'].module_title.unique()
# Out:
# array(['Концептуальный дизайн', 'Специализация и личное позиционирование',
#        'Иконки', ' Введение в UX', 'Бонус-модуль #1',
#        'Портреты пользователей и CJM', 'Readymag', 'Типографика PRO',
#        'Бонус-модуль #2', 'Продвинутая презентация',
#        'Cinema 4D + Blender', 'Копирайтинг', 'Бонус-модуль #3',
#        'Adobe XD', 'Кейс на 1000 лайков',
#        'Информация о дипломном проекте',
#        'План развития дизайнера на 3 года'], dtype=object)

# %% [markdown]
# 1. Тестовые студенты с прогрессами до 1 декабря 2017 года - их мы просто удалим
# 2. Студенты, записанные на один курс
#     1) закончившие или почти закончившие обучение (приступившие к последнему модулю)
#     2) начавшие заниматься недавно (менее двух месяцев до 22 июля 2019)
#     3) начавшие заниматься давно, но не сделавшие ни одного ДЗ
#     4) забросившие его на ранней стадии (менее 3 ДЗ)
#     5) Забросившие его, прорешав несколько модулей (3 и более ДЗ)
#     6) Закончившие или продолжающие заниматься
# 3. Студенты, записанные на несколько курсов
#     1) Перешедшие с одного курса на другой недавно
#     2) Перешедшие с одного курса на другой и забросившие его на ранней стадии (прогресс по всем курсам заброшен)
#     3) Перешедшие с одного курса на другой и забросившие его прорешав несколько модулей (прогресс по всем курсам заброшен)
#     4) Перешедшие с одного курса на другой (прогресс по одним курсам заброшен, но по другим завершён или в процессе)(или взято два курса, решается один, а второй оставлен на потом)
#     5) Занимающиеся на нескольких курсах сразу недавно
#     6) Занимающиеся на нескольких курсах сразу (прогресс по нескольким курсам завершен или в процессе)

# %%
len(failed_stud_multi.student_id.unique())
# Out:
# 526

# %%
failed_stud_multi
# Out:
#       finish_date  start_date                       progress_id  \
# 13     2019-07-03  2019-07-02  73e17a05355852fe65b785c82c37d1ad
# 14     2019-07-22  2019-07-11  73e17a05355852fe65b785c82c37d1ad
# 25     2019-07-09  2019-06-24  d8f96c352ebf58682962795577fb01bc
# 26     2019-07-22  2019-07-10  d8f96c352ebf58682962795577fb01bc
# 27     2019-06-21  2019-06-18  04ace4fe130d90c801e24eea13ee808e
# ...           ...         ...                               ...
# 11140  2019-06-08  2019-05-29  96d11030950a82f8dcf85269e7d3137c
# 11225  2019-07-22  2019-07-15  06d124dc91b1e50a57d2092de2aee15e
# 11232  2019-05-29  2019-05-28  ec0d53d87ce9162416214d0ce89938f0
# 11233  2019-05-28  2019-05-27  ec0d53d87ce9162416214d0ce89938f0
# 11234  2019-05-24  2019-05-22  ec0d53d87ce9162416214d0ce89938f0
#
#        module_number  lesson_number status                        student_id  \
# 13                 1              6   done  ed235f47e16da6e83d3f1cb511f38ea6
# ...

# %%
qq = failed_stud_multi.groupby(['student_id'])['title'].nunique().to_frame()
#ww = failed_stud_multi.groupby(['student_id'])['title'].nunique().to_frame().reset_index().title
#failed_stud_multi.groupby(['student_id'])['title'].nunique().to_frame().reset_index().student_id
qq
# Out:
#                                   title
# student_id
# 00c6fcbb64727b2d4677f44f0f425754      1
# 00e0705b5d5dde933ecc456c5df455ab      1
# 0286a5606c8b63255e5fae4ae00c0cc3      2
# 028bd3eb58bb3cb6d86b604079f48ca7      1
# 02e1e2c7a31699e1440056fbde89b89a      1
# ...                                 ...
# fcaeaccb59dcffb808d18ce9e2775d7f      1
# feac8bf7b837c63ba0959c41a8c9dc13      1
# ff38b14e11ab4189f28109f0f12ecbf8      2
# ffaa1bee55e8dfdfa2125f441de35c43      1
# ffc4008315dff59b29e7733f43f85913      1
#
# [526 rows x 1 columns]

# %%
for i in qq.index:
    for j in range(qq.title[i]):
        if failed_stud_multi[failed_stud_multi['']]
# Out:
#   File "<ipython-input-658-f60e98ca37d7>", line 3
#     if failed_stud_multi[failed_stud_multi['']]
#                                                ^
# SyntaxError: invalid syntax

# %%
qq = list(failed_stud_multi.groupby(['student_id']))[0][1]

ww = qq.groupby(['title']).last()
#for i in range(ww.count()[0]):
#   if ww.iloc[i]

# %%
def qwer(df):
    tempdf = df.groupby(['title']).last()
    if tempdf[(tempdf['start_date'] > '2019-05-22') & (tempdf[''])]

failed_stud_multi.groupby(['student_id']).agg()

# %%
failed_stud_multi_temp = failed_stud_multi.groupby(['progress_id', 'title']).count()
failed_stud_multi_one_active = failed_stud_multi_temp[failed_stud_multi_temp['status'] < 4].reset_index()
failed_stud_multi_one_active = failed_stud_multi_one_active.groupby(['progress_id'])['title'].nunique()
#failed_stud_multi_has_active_one_list = failed_stud_multi_has_active[temp == 1]
#failed_stud_multi_has_active_multi_list = failed_stud_multi_has_active[temp > 1]

#183 студента у которых несколько курсов и во всех менее 3 прогрессов

# %% [markdown]
# Список прогрессов.
# Удаляем из failed_stud эти прогрессы, эти студенты попадут в failed_stud_one.

# %%
failed_stud_multi_no_active = failed_stud_multi[~(failed_stud_multi['student_id'].isin(failed_stud_multi_has_active.index)) & (failed_stud_multi['start_date'] < '2019-05-22')].sort_values(['student_id', 'title'])

failed_stud_multi_no_active_1 = failed_stud_multi[~(failed_stud_multi['student_id'].isin(failed_stud_multi_has_active.index)) & (failed_stud_multi['start_date'] > '2019-04-22')].sort_values(['student_id', 'title'])

# %%
failed_stud_multi_no_active.student_id.nunique()

# %% [markdown]
# 1) По одному курсу есть прогресс менее 2 месяцев назад, остальные заброшены - дата последнего выполненного дз более 2 месяцев
# 2) По одному курсу есть прогресс более 2 месяцев назад, остальные заброшены... т.е. все заброшены
# 3) Есть прогресс по более чем одному курсу менее 2 месяцев назад, остальные заброшены или их нет
